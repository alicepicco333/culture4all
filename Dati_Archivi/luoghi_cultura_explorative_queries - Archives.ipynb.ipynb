# %%
#Explorative query for defining which and how many type of entities there are inside the luoghi della cultura dataset

from rdflib import Graph
import csv
import pandas as pd
from IPython.display import display

# Load your RDF file
rdf_file =  r"C:\Users\HWRUser\Desktop\DHDK Course\Information Visualization\Data_Italian_publishers\dataset_luoghi_cultura.rdf"
g = Graph()
g.parse(rdf_file, format="xml")  


#Query for identifying the type of entities inside the dataset 
query_1 = """
 PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
 PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
 PREFIX cis: <http://dati.beniculturali.it/cis/>
 PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>
 PREFIX dc: <http://purl.org/dc/elements/1.1/>

 SELECT ?entity ?entityType
  WHERE {
   {
       # ?entity a ?entityType.
    }
   
    UNION
  {
    # ?entity dc:type ?entityType .
  }
   
}

"""


# Perform the query
results = g.query(query_1)

#Dataframe for Entity Type
data_Entity_Type= []
for row in results:
    data_Entity_Type.append({'Entity_ID': str(row['entity']), 'Entity_Type': str(row['entityType'])})
df_entity_Type = pd.DataFrame(data_Entity_Type)

#Dataframe for counting the Entities according to their type
entity_type_counts = df_entity_Type.groupby('Entity_Type').size().reset_index(name='Count')

display(df_entity_Type)
display(entity_type_counts)
# Out:
#                                                 Entity_ID  \
# 0       http://dati.beniculturali.it/mibact/luoghi/res...
# 1       http://dati.beniculturali.it/mibact/luoghi/res...
# 2       http://dati.beniculturali.it/mibact/luoghi/res...
# 3       http://dati.beniculturali.it/mibact/luoghi/res...
# 4       http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                   ...
# 134441  http://dati.beniculturali.it/mibact/luoghi/res...
# 134442  http://dati.beniculturali.it/mibact/luoghi/res...
# 134443  http://dati.beniculturali.it/mibact/luoghi/res...
# 134444  http://dati.beniculturali.it/mibact/luoghi/res...
# 134445  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                               Entity_Type
# 0       https://w3id.org/italia/onto/SM/OnlineContactP...
# 1       https://w3id.org/italia/onto/SM/OnlineContactP...
# 2       https://w3id.org/italia/onto/SM/OnlineContactP...
# 3       https://w3id.org/italia/onto/SM/OnlineContactP...
# 4       https://w3id.org/italia/onto/SM/OnlineContactP...
# ...                                                   ...
# 134441                             I tesori della Cultura
# 134442                                  Istituto Centrale
# 134443        Soprintendenza Archivistica e Bibliografica
# 134444                                             Comune
# 134445                        Amministrazione dello Stato
#
# [134446 rows x 2 columns]
#                                           Entity_Type  Count
# 0                                               Altro    177
# 1                         Amministrazione dello Stato      1
# 2                                 Architettura Civile    175
# 3                            Architettura Fortificata    130
# 4                                            Archivio     11
# 5                                   Archivio di Stato    142
# 6                                   Area Archeologica    386
# 7                                          Biblioteca     34
# 8                                  Biblioteca Statale     45
# 9                          Chiesa o edificio di culto    330
# 10                                             Comune      1
# 11                                         Fondazione      4
# 12                             I tesori della Cultura      1
# 13                                  Istituto Centrale      1
# 14              Istituto dotato di autonomia speciale      1
# 15  Istituto dotato di autonomia speciale, di rile...      1
# 16                                          Monumento    158
# 17                                Monumento Funerario     18
# 18               Monumento di Archeologia Industriale     17
# 19                       Museo, Galleria e/o raccolta   4681
# 20                                 Parco Archeologico     78
# 21  Parco o Giardino di interesse storico o artistico     63
# 22                                            Regione      1
# 23        Soprintendenza Archivistica e Bibliografica      1
# 24   Villa o Palazzo di interesse storico o artistico    184
# 25     http://dati.beniculturali.it/cis/CISNameInTime   6641
# 26      http://dati.beniculturali.it/cis/CreativeWork   5821
# 27  http://dati.beniculturali.it/cis/CulturalInsti...   6641
# 28   http://dati.beniculturali.it/cis/HolderOfArchive     11
# 29           http://dati.beniculturali.it/cis/Library     34
# 30              http://dati.beniculturali.it/cis/Site   6638
# 31  http://dati.beniculturali.it/cis/SubjectDiscip...     21
# 32         http://purl.org/net/provenance/ns#DataItem   6641
# 33  https://w3id.org/italia/onto/AccessCondition/B...      3
# 34  https://w3id.org/italia/onto/AccessCondition/O...  10500
# 35           https://w3id.org/italia/onto/CLV/Address   6638
# 36              https://w3id.org/italia/onto/CLV/City   2645
# 37    https://w3id.org/italia/onto/CLV/CivicNumbering   1433
# 38           https://w3id.org/italia/onto/CLV/Country      1
# 39           https://w3id.org/italia/onto/CLV/Feature   2776
# 40          https://w3id.org/italia/onto/CLV/Geometry   6124
# 41      https://w3id.org/italia/onto/CLV/GeometryType      1
# 42          https://w3id.org/italia/onto/CLV/Province    110
# 43            https://w3id.org/italia/onto/CLV/Region     20
# 44     https://w3id.org/italia/onto/CLV/StreetToponym   6631
# 45             https://w3id.org/italia/onto/POT/Offer   5077
# 46  https://w3id.org/italia/onto/POT/PriceSpecific...   5077
# 47            https://w3id.org/italia/onto/POT/Ticket   5077
# 48               https://w3id.org/italia/onto/RO/Role      3
# 49    https://w3id.org/italia/onto/RO/TimeIndexedRole  14752
# 50              https://w3id.org/italia/onto/SM/Email   5210
# 51  https://w3id.org/italia/onto/SM/OnlineContactP...  11292
# 52          https://w3id.org/italia/onto/SM/Telephone   6337
# 53            https://w3id.org/italia/onto/SM/WebSite   4291
# 54                   https://w3id.org/italia/onto/l0/      1
# 55              https://w3id.org/italia/onto/l0/Agent   1358

# %%
#Query for identifying the Archive IDs, Names, Cities and Regions

query_2 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX cis: <http://dati.beniculturali.it/cis/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>

SELECT ?archive ?archivelabel ?archiveCity ?archiveRegion
WHERE {

   {
    # ?archive dc:type "Archivio di Stato".
  }
  UNION
  {
   # ?archive dc:type "Archivio".
  }


  # ?archive rdf:type cis:CulturalInstituteOrSite .
  # ?archive rdfs:label ?archivelabel .
  # ?archive cis:hasSite ?archiveSite.
  # ?archiveSite cis:siteAddress ?archiveAddress.
  # ?archiveAddress clvapit:hasRegion ?archiveRegion.
  # ?archiveAddress clvapit:hasCity ?archiveCity.
}
"""


# Perform the query
results = g.query(query_2)


#Archives Dataframe
data_Archives = []
for row in results:
    data_Archives.append({'Archive_ID': str(row['archive']), 'Archive_Name': str(row['archivelabel']), 'Archive_City': str(row['archiveCity']),'Archive_Region': str(row['archiveRegion']) })
df_archives = pd.DataFrame(data_Archives)

#Dataframes for counting archives by their city and region
archive_region_counts = df_archives.groupby('Archive_Region').size().reset_index(name='Count')
archive_city_counts = df_archives.groupby('Archive_City').size().reset_index(name='Count')
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)   # No truncation of column width

display(df_archives)
display(archive_region_counts)
display(archive_city_counts)

#CSV from all Dataframes for Archives
csv_file_archives = "Archives_Luoghi_Cultura.csv"
df_archives.to_csv(csv_file_archives, index=False, encoding='utf-8')
print(f"Results have been written to {csv_file_archives}")

csv_file_archives_region_count = "Archives_region_count_Luoghi_Cultura.csv"
archive_region_counts.to_csv(csv_file_archives_region_count, index=False, encoding='utf-8')
print(f"Results have been written to {csv_file_archives_region_count}")


csv_file_archives_city_count = "Archives_city_count_Luoghi_Cultura.csv"
archive_city_counts.to_csv(csv_file_archives_city_count, index=False, encoding='utf-8')
print(f"Results have been written to {csv_file_archives_city_count}")
# Out:
#                                                                              Archive_ID  \
# 0      http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/7183
# 1    http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/125234
# 2    http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/116648
# 3    http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/133053
# 4      http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/7224
# ..                                                                                  ...
# 148  http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/126368
# 149  http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/133728
# 150  http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/101958
# 151  http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/108242
# 152  http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/132097
#
#                                                                               Archive_Name  \
# 0                                                       Archivio di Stato di Reggio Emilia
# 1                                                              Archivio di Stato di Trento
# 2                                           Archivio di Stato di Bologna, Sezione di Imola
# 3                                                            Archivio centrale dello Stato
# 4    Soprintendenza Archivistica della Sicilia - Archivio di Stato di Palermo. Sede Gancia
# ..                                                                                     ...
# 148                                                            Archivio di Stato di Varese
# 149                                                                             Casa Zegna
# 150                                                         Collezione storica ATC Bologna
# 151                                                   Raccolta Archivio Toraldo di Francia
# 152                                                                   Fondazione Memofonte
#
#                                                                     Archive_City  \
# 0    http://dati.beniculturali.it/mibact/luoghi/resource/City/Reggio_nell_Emilia
# 1                http://dati.beniculturali.it/mibact/luoghi/resource/City/Trento
# 2                 http://dati.beniculturali.it/mibact/luoghi/resource/City/Imola
# 3                  http://dati.beniculturali.it/mibact/luoghi/resource/City/Roma
# 4               http://dati.beniculturali.it/mibact/luoghi/resource/City/Palermo
# ..                                                                           ...
# 148              http://dati.beniculturali.it/mibact/luoghi/resource/City/Varese
# 149             http://dati.beniculturali.it/mibact/luoghi/resource/City/Trivero
# 150             http://dati.beniculturali.it/mibact/luoghi/resource/City/Bologna
# 151              http://dati.beniculturali.it/mibact/luoghi/resource/City/Tropea
# 152             http://dati.beniculturali.it/mibact/luoghi/resource/City/Firenze
#
#                                                                      Archive_Region
# 0         http://dati.beniculturali.it/mibact/luoghi/resource/Region/Emilia-Romagna
# 1    http://dati.beniculturali.it/mibact/luoghi/resource/Region/Trentino-Alto_Adige
# 2         http://dati.beniculturali.it/mibact/luoghi/resource/Region/Emilia-Romagna
# 3                  http://dati.beniculturali.it/mibact/luoghi/resource/Region/Lazio
# 4                http://dati.beniculturali.it/mibact/luoghi/resource/Region/Sicilia
# ..                                                                              ...
# 148            http://dati.beniculturali.it/mibact/luoghi/resource/Region/Lombardia
# 149             http://dati.beniculturali.it/mibact/luoghi/resource/Region/Piemonte
# 150       http://dati.beniculturali.it/mibact/luoghi/resource/Region/Emilia-Romagna
# 151             http://dati.beniculturali.it/mibact/luoghi/resource/Region/Calabria
# 152              http://dati.beniculturali.it/mibact/luoghi/resource/Region/Toscana
#
# [153 rows x 4 columns]
#                                                                       Archive_Region  \
# 0                 http://dati.beniculturali.it/mibact/luoghi/resource/Region/Abruzzo
# 1              http://dati.beniculturali.it/mibact/luoghi/resource/Region/Basilicata
# 2                http://dati.beniculturali.it/mibact/luoghi/resource/Region/Calabria
# 3                http://dati.beniculturali.it/mibact/luoghi/resource/Region/Campania
# 4          http://dati.beniculturali.it/mibact/luoghi/resource/Region/Emilia-Romagna
# 5   http://dati.beniculturali.it/mibact/luoghi/resource/Region/Friuli-Venezia_Giulia
# 6                   http://dati.beniculturali.it/mibact/luoghi/resource/Region/Lazio
# 7                 http://dati.beniculturali.it/mibact/luoghi/resource/Region/Liguria
# 8               http://dati.beniculturali.it/mibact/luoghi/resource/Region/Lombardia
# 9                  http://dati.beniculturali.it/mibact/luoghi/resource/Region/Marche
# 10                 http://dati.beniculturali.it/mibact/luoghi/resource/Region/Molise
# 11               http://dati.beniculturali.it/mibact/luoghi/resource/Region/Piemonte
# 12                 http://dati.beniculturali.it/mibact/luoghi/resource/Region/Puglia
# 13               http://dati.beniculturali.it/mibact/luoghi/resource/Region/Sardegna
# 14                http://dati.beniculturali.it/mibact/luoghi/resource/Region/Sicilia
# 15                http://dati.beniculturali.it/mibact/luoghi/resource/Region/Toscana
# 16    http://dati.beniculturali.it/mibact/luoghi/resource/Region/Trentino-Alto_Adige
# 17                 http://dati.beniculturali.it/mibact/luoghi/resource/Region/Umbria
# 18                 http://dati.beniculturali.it/mibact/luoghi/resource/Region/Veneto
#
#     Count
# 0       7
# 1       3
# 2       9
# 3       5
# 4      13
# 5       5
# 6       7
# 7       8
# 8      10
# 9      13
# 10      2
# 11     11
# 12      7
# 13      4
# 14     16
# 15     15
# 16      2
# 17      6
# 18     10
#                                                                        Archive_City  \
# 0    http://dati.beniculturali.it/mibact/luoghi/resource/City/Acquaviva_delle_Fonti
# 1                http://dati.beniculturali.it/mibact/luoghi/resource/City/Agrigento
# 2              http://dati.beniculturali.it/mibact/luoghi/resource/City/Alessandria
# 3                   http://dati.beniculturali.it/mibact/luoghi/resource/City/Aliano
# 4                   http://dati.beniculturali.it/mibact/luoghi/resource/City/Ancona
# ..                                                                              ...
# 130                 http://dati.beniculturali.it/mibact/luoghi/resource/City/Verona
# 131          http://dati.beniculturali.it/mibact/luoghi/resource/City/Vibo_Valentia
# 132                http://dati.beniculturali.it/mibact/luoghi/resource/City/Vicenza
# 133             http://dati.beniculturali.it/mibact/luoghi/resource/City/Vicopisano
# 134                http://dati.beniculturali.it/mibact/luoghi/resource/City/Viterbo
#
#      Count
# 0        1
# 1        2
# 2        1
# 3        1
# 4        4
# ..     ...
# 130      1
# 131      1
# 132      1
# 133      1
# 134      1
#
# [135 rows x 2 columns]
# Results have been written to Archives_Luoghi_Cultura.csv
# Results have been written to Archives_region_count_Luoghi_Cultura.csv
# Results have been written to Archives_city_count_Luoghi_Cultura.csv
