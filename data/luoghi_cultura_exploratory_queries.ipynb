# %%
"""In the contest of the research question of the project we tried to anyalize the luoghi della cultura dataset to understand which and how many entities were contained 
(with a focus specifically related to finding libraries, museumns and archives), counting them for regions and cities and then to find out any museum, library, archive with a
 free entry or a ticket cost price."""


from rdflib import Graph
import csv
import pandas as pd
from IPython.display import display

# Load the  datastet luoghi della cultura RDF file
rdf_file =  r"C:\Users\HWRUser\Desktop\DHDK Course\Information Visualization\Data_Italian_publishers\dataset_luoghi_cultura.rdf"
g = Graph()
g.parse(rdf_file, format="xml") 


#Exploratory Query for identifying the type of entities inside the dataset 
query_0 = """
 PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
 PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
 PREFIX cis: <http://dati.beniculturali.it/cis/>
 PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>
 PREFIX dc: <http://purl.org/dc/elements/1.1/>

 SELECT ?entity ?entityType
  WHERE {
   {
       # ?entity a ?entityType.
    }
   
    UNION
  {
    # ?entity dc:type ?entityType .
  }
   
}

"""

#Performing the query
results = g.query(query_0)

#Dataframe for Entity Types
data_Entity_Type= []
for row in results:
    data_Entity_Type.append({'Entity_ID': str(row['entity']), 'Entity_Type': str(row['entityType'])})
df_entity_Type = pd.DataFrame(data_Entity_Type)

#Dataframe for counting the Entities according to their type
entity_type_counts = df_entity_Type.groupby('Entity_Type').size().reset_index(name='Count')

#Displaying entity types and their counts
display(df_entity_Type)
display(entity_type_counts)
# Out:
#                                                 Entity_ID  \
# 0       http://dati.beniculturali.it/mibact/luoghi/res...
# 1       http://dati.beniculturali.it/mibact/luoghi/res...
# 2       http://dati.beniculturali.it/mibact/luoghi/res...
# 3       http://dati.beniculturali.it/mibact/luoghi/res...
# 4       http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                   ...
# 134441  http://dati.beniculturali.it/mibact/luoghi/res...
# 134442  http://dati.beniculturali.it/mibact/luoghi/res...
# 134443  http://dati.beniculturali.it/mibact/luoghi/res...
# 134444  http://dati.beniculturali.it/mibact/luoghi/res...
# 134445  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                               Entity_Type
# 0       https://w3id.org/italia/onto/SM/OnlineContactP...
# 1       https://w3id.org/italia/onto/SM/OnlineContactP...
# 2       https://w3id.org/italia/onto/SM/OnlineContactP...
# 3       https://w3id.org/italia/onto/SM/OnlineContactP...
# 4       https://w3id.org/italia/onto/SM/OnlineContactP...
# ...                                                   ...
# 134441                             I tesori della Cultura
# 134442                                  Istituto Centrale
# 134443        Soprintendenza Archivistica e Bibliografica
# 134444                                             Comune
# 134445                        Amministrazione dello Stato
#
# [134446 rows x 2 columns]
#                                           Entity_Type  Count
# 0                                               Altro    177
# 1                         Amministrazione dello Stato      1
# 2                                 Architettura Civile    175
# 3                            Architettura Fortificata    130
# 4                                            Archivio     11
# 5                                   Archivio di Stato    142
# 6                                   Area Archeologica    386
# 7                                          Biblioteca     34
# 8                                  Biblioteca Statale     45
# 9                          Chiesa o edificio di culto    330
# 10                                             Comune      1
# 11                                         Fondazione      4
# 12                             I tesori della Cultura      1
# 13                                  Istituto Centrale      1
# 14              Istituto dotato di autonomia speciale      1
# 15  Istituto dotato di autonomia speciale, di rile...      1
# 16                                          Monumento    158
# 17                                Monumento Funerario     18
# 18               Monumento di Archeologia Industriale     17
# 19                       Museo, Galleria e/o raccolta   4681
# 20                                 Parco Archeologico     78
# 21  Parco o Giardino di interesse storico o artistico     63
# 22                                            Regione      1
# 23        Soprintendenza Archivistica e Bibliografica      1
# 24   Villa o Palazzo di interesse storico o artistico    184
# 25     http://dati.beniculturali.it/cis/CISNameInTime   6641
# 26      http://dati.beniculturali.it/cis/CreativeWork   5821
# 27  http://dati.beniculturali.it/cis/CulturalInsti...   6641
# 28   http://dati.beniculturali.it/cis/HolderOfArchive     11
# 29           http://dati.beniculturali.it/cis/Library     34
# 30              http://dati.beniculturali.it/cis/Site   6638
# 31  http://dati.beniculturali.it/cis/SubjectDiscip...     21
# 32         http://purl.org/net/provenance/ns#DataItem   6641
# 33  https://w3id.org/italia/onto/AccessCondition/B...      3
# 34  https://w3id.org/italia/onto/AccessCondition/O...  10500
# 35           https://w3id.org/italia/onto/CLV/Address   6638
# 36              https://w3id.org/italia/onto/CLV/City   2645
# 37    https://w3id.org/italia/onto/CLV/CivicNumbering   1433
# 38           https://w3id.org/italia/onto/CLV/Country      1
# 39           https://w3id.org/italia/onto/CLV/Feature   2776
# 40          https://w3id.org/italia/onto/CLV/Geometry   6124
# 41      https://w3id.org/italia/onto/CLV/GeometryType      1
# 42          https://w3id.org/italia/onto/CLV/Province    110
# 43            https://w3id.org/italia/onto/CLV/Region     20
# 44     https://w3id.org/italia/onto/CLV/StreetToponym   6631
# 45             https://w3id.org/italia/onto/POT/Offer   5077
# 46  https://w3id.org/italia/onto/POT/PriceSpecific...   5077
# 47            https://w3id.org/italia/onto/POT/Ticket   5077
# 48               https://w3id.org/italia/onto/RO/Role      3
# 49    https://w3id.org/italia/onto/RO/TimeIndexedRole  14752
# 50              https://w3id.org/italia/onto/SM/Email   5210
# 51  https://w3id.org/italia/onto/SM/OnlineContactP...  11292
# 52          https://w3id.org/italia/onto/SM/Telephone   6337
# 53            https://w3id.org/italia/onto/SM/WebSite   4291
# 54                   https://w3id.org/italia/onto/l0/      1
# 55              https://w3id.org/italia/onto/l0/Agent   1358

# %%
"""During the early stages of studying the dataset, we noticed that there were several entity places whose instutional description did not match exactly with its physical description, 
so it was decided to investigate this discrepancy further."""

#Exploratory Query for identifying the Other entities as Places, their IDs, Names, Cities, Regions and Types

query_1 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX cis: <http://dati.beniculturali.it/cis/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>


SELECT ?OtherPlace ?OhterPlaceLabel ?OhterPlaceCity ?OtherPlaceRegion ?OtherPlaceType
WHERE {
  # ?OtherPlace rdf:type cis:CulturalInstituteOrSite .
  # ?OtherPlace dc:type ?OtherPlaceType.
  # ?OtherPlace rdfs:label ?OhterPlaceLabel .
  # ?OtherPlace cis:hasSite ?OtherPlaceSite.
  # ?OtherPlaceSite cis:siteAddress ?OtherPlaceAddress.
  # ?OtherPlaceAddress clvapit:hasRegion ?OtherPlaceRegion.
  # ?OtherPlaceAddress clvapit:hasCity ?OhterPlaceCity.
  FILTER NOT EXISTS { ?OtherPlace dc:type "Biblioteca" }
  FILTER NOT EXISTS { ?OtherPlace dc:type "Museo, Galleria e/o raccolta" }
  FILTER NOT EXISTS { ?OtherPlace dc:type "Archivio di Stato" }
  FILTER NOT EXISTS { ?OtherPlace dc:type "Archivio" }
  FILTER NOT EXISTS { ?OtherPlace dc:type "Biblioteca Statale" }



}
"""


#Perform the query
results = g.query(query_1)


#Ohter Places Dataframe
data_OtherPlaces = []
for row in results:
    data_OtherPlaces.append({'OtherPlace_ID': str(row['OtherPlace']), 'OtherPlace_Name': str(row['OhterPlaceLabel']), 'OtherPlace_Type': str(row['OtherPlaceType']), 'OtherPlace_City': str(row['OhterPlaceCity']), 'OtherPlace_Region': str(row['OtherPlaceRegion'])})
df_OtherPlaces = pd.DataFrame(data_OtherPlaces)

#Dtaframes for counting Ohter Places Types and their number for each region
OtherPlace_Type_counts = df_OtherPlaces.groupby('OtherPlace_Type').size().reset_index(name='Count')


#Displaying OtherPlaces DataFrames and their type counts
display(df_OtherPlaces)
display(OtherPlace_Type_counts)

#CSV files from all OtherType Dataframes
csv_file_OtherPlaces = "OtherPlaces.csv"
df_OtherPlaces.to_csv(csv_file_OtherPlaces, index=False, encoding='utf-8')
print(f"Results have been written to {csv_file_OtherPlaces}")

# csv_file_OtherPlaces_Type = "OtherPlaces_Type_count.csv"
# OtherPlace_Type_counts.to_csv(csv_file_OtherPlaces_Type, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_OtherPlaces_Type}")
# Out:
#                                           OtherPlace_ID  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1721  http://dati.beniculturali.it/mibact/luoghi/res...
# 1722  http://dati.beniculturali.it/mibact/luoghi/res...
# 1723  http://dati.beniculturali.it/mibact/luoghi/res...
# 1724  http://dati.beniculturali.it/mibact/luoghi/res...
# 1725  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                OtherPlace_Name             OtherPlace_Type  \
# 0                    Museo Annibale Di Francia  Chiesa o edificio di culto
# 1                  Madonna della Pietà, Chiesa  Chiesa o edificio di culto
# 2              Museo della Fondazione Whitaker                       Altro
# 3                          Seminario diocesano  Chiesa o edificio di culto
# 4            San Michele Arcangelo - Catacombe           Area Archeologica
# ...                                        ...                         ...
# 1721           Teatro comunale di Fontanellato         Architettura Civile
# 1722  Museo diocesano d'arte sacra di Trivento  Chiesa o edificio di culto
# 1723                        Palazzo del Senato                       Altro
# 1724                            Cappella Manin  Chiesa o edificio di culto
# 1725                      Torre del Candeliere         Architettura Civile
#
#                                         OtherPlace_City  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1721  http://dati.beniculturali.it/mibact/luoghi/res...
# 1722  http://dati.beniculturali.it/mibact/luoghi/res...
# 1723  http://dati.beniculturali.it/mibact/luoghi/res...
# 1724  http://dati.beniculturali.it/mibact/luoghi/res...
# 1725  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                       OtherPlace_Region
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1721  http://dati.beniculturali.it/mibact/luoghi/res...
# 1722  http://dati.beniculturali.it/mibact/luoghi/res...
# 1723  http://dati.beniculturali.it/mibact/luoghi/res...
# 1724  http://dati.beniculturali.it/mibact/luoghi/res...
# 1725  http://dati.beniculturali.it/mibact/luoghi/res...
#
# [1726 rows x 5 columns]
#                                       OtherPlace_Type  Count
# 0                                               Altro    177
# 1                         Amministrazione dello Stato      1
# 2                                 Architettura Civile    175
# 3                            Architettura Fortificata    130
# 4                                   Area Archeologica    385
# 5                          Chiesa o edificio di culto    329
# 6                                              Comune      1
# 7                                          Fondazione      4
# 8                              I tesori della Cultura      1
# 9                                   Istituto Centrale      1
# 10              Istituto dotato di autonomia speciale      1
# 11  Istituto dotato di autonomia speciale, di rile...      1
# 12                                          Monumento    158
# 13                                Monumento Funerario     18
# 14               Monumento di Archeologia Industriale     17
# 15                                 Parco Archeologico     78
# 16  Parco o Giardino di interesse storico o artistico     63
# 17                                            Regione      1
# 18        Soprintendenza Archivistica e Bibliografica      1
# 19   Villa o Palazzo di interesse storico o artistico    184
# Results have been written to OtherPlaces.csv

# %%
""" The next phase was to identify all the libraries, musuems and archives entities counting and diving them for region and city. 
We started our search from libraries."""

#Exploratory Query for identifying all the libraries IDs, Names, Cities and Regions

query_2 = """
 PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
 PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
 PREFIX cis: <http://dati.beniculturali.it/cis/>
 PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>
 PREFIX dc: <http://purl.org/dc/elements/1.1/>
 PREFIX geo1: <http://www.w3.org/2003/01/geo/wgs84_pos#>

 SELECT ?library ?librarylabel ?libraryCity ?libraryRegion ?librarylatitude ?librarylongitude 
 WHERE {

   {
    # ?library a cis:Library .
  }
  UNION
  {
    # ?library dc:type "Biblioteca Statale" .
  }

   # ?library a cis:CulturalInstituteOrSite.
   # ?library rdfs:label ?librarylabel.
   # ?library cis:hasSite ?librarysite.
   # ?librarysite cis:siteAddress ?libraryAddress.
   # ?libraryAddress clvapit:hasRegion ?libraryRegion.
   # ?libraryAddress clvapit:hasCity ?libraryCity.
   # ?library geo1:lat ?librarylatitude.
   # ?library geo1:long ?librarylongitude.
 } 
 
"""


# Perform the query
results = g.query(query_2)

#Libraries Dataframe
data_Libraries = []
for row in results:
    data_Libraries.append({'Library_ID': str(row['library']), 'Library_Name': str(row['librarylabel']),'Library_City': str(row['libraryCity']), 'Library_Region': str(row['libraryRegion']),'Library_Latitude': str(row['librarylatitude']), 'Library_Longitude': str(row['librarylongitude'])})
df_Libraries = pd.DataFrame(data_Libraries)

# List of IDs to remove that are not libraries:some of the entity libraries were classified in the dataset as libraries but after an in-depth search it was find out that they were not exactly libraries. For deciding if it was the case these were compared with the same entity identified in WikiData.
IDs_to_remove=["http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102857",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102889",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102891",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/101975",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102879",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102917",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102858",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102876",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102853",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/110257",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102864",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102855"]

# Find rows to remove in Library_ID
rows_to_remove = df_Libraries[df_Libraries['Library_ID'].isin(IDs_to_remove)].index
library_df = df_Libraries.drop(rows_to_remove)
library_df.reset_index(drop=True, inplace=True)


#Dataframe for counting number of libraries for region 
library_region_counts = library_df.groupby('Library_Region').size().reset_index(name='Count')
# Calculate the total count
total_library_region_count = library_region_counts['Count'].sum()
# Create a DataFrame for the total row
total_row = pd.DataFrame({'Library_Region': ['Total'], 'Count': [total_library_region_count]})
# Append the total row to the grouped DataFrame
library_region_counts= pd.concat([library_region_counts, total_row], ignore_index=True)


# #Dataframes for counting number of libraries for city
library_city_counts = library_df.groupby('Library_City').size().reset_index(name='Count')
total_library_city_count = library_city_counts['Count'].sum()
# Create a DataFrame for the total row
total_row = pd.DataFrame({'Library_City': ['Total'], 'Count': [total_library_city_count]})
# Append the total row to the grouped DataFrame
library_city_counts= pd.concat([library_city_counts, total_row], ignore_index=True)

#Displaying library DataFrame, library region and library city count dataframe
display(library_df)
display(library_region_counts)
display(library_city_counts)

# CSV files from all Dataframes for libraries
# csv_file_libraries = "Libraries_Luoghi_Cultura.csv"
# library_df.to_csv(csv_file_libraries, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_libraries}")

# csv_file_library_region_count = "Libraries_Region_Count_Luoghi_Cultura.csv"
# library_region_counts.to_csv(csv_file_library_region_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_library_region_count}")

# csv_file_library_city_count = "Libraries_City_Count_Luoghi_Cultura.csv"
# library_city_counts.to_csv(csv_file_library_city_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_library_city_count}")
# Out:
#                                            Library_ID  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...
# 1   http://dati.beniculturali.it/mibact/luoghi/res...
# 2   http://dati.beniculturali.it/mibact/luoghi/res...
# 3   http://dati.beniculturali.it/mibact/luoghi/res...
# 4   http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                ...
# 56  http://dati.beniculturali.it/mibact/luoghi/res...
# 57  http://dati.beniculturali.it/mibact/luoghi/res...
# 58  http://dati.beniculturali.it/mibact/luoghi/res...
# 59  http://dati.beniculturali.it/mibact/luoghi/res...
# 60  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                          Library_Name  \
# 0        Centro dantesco dei Frati Minori Conventuali
# 1                            Biblioteca 'Mario Gromo'
# 2                                 Biblioteca comunale
# 3                         Biblioteca comunale - Museo
# 4                                Biblioteca Classense
# ..                                                ...
# 56                Biblioteca Universitaria di Sassari
# 57                     Musei Reali - Biblioteca Reale
# 58         Biblioteca Statale Stelio Crise di Trieste
# 59  San Matteo - Sede distaccata Biblioteca Univer...
# 60                    Biblioteca Nazionale di Potenza
#
#                                          Library_City  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...
# 1   http://dati.beniculturali.it/mibact/luoghi/res...
# 2   http://dati.beniculturali.it/mibact/luoghi/res...
# 3   http://dati.beniculturali.it/mibact/luoghi/res...
# 4   http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                ...
# 56  http://dati.beniculturali.it/mibact/luoghi/res...
# 57  http://dati.beniculturali.it/mibact/luoghi/res...
# 58  http://dati.beniculturali.it/mibact/luoghi/res...
# 59  http://dati.beniculturali.it/mibact/luoghi/res...
# 60  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                        Library_Region Library_Latitude  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...         44.41629
# 1   http://dati.beniculturali.it/mibact/luoghi/res...        45.081963
# 2   http://dati.beniculturali.it/mibact/luoghi/res...         41.63192
# 3   http://dati.beniculturali.it/mibact/luoghi/res...        40.184994
# 4   http://dati.beniculturali.it/mibact/luoghi/res...        44.414177
# ..                                                ...              ...
# 56  http://dati.beniculturali.it/mibact/luoghi/res...        40.722702
# 57  http://dati.beniculturali.it/mibact/luoghi/res...         45.07285
# 58  http://dati.beniculturali.it/mibact/luoghi/res...         45.64559
# 59  http://dati.beniculturali.it/mibact/luoghi/res...          43.7152
# 60  http://dati.beniculturali.it/mibact/luoghi/res...        40.634987
#
#    Library_Longitude
# 0          12.200871
# 1           7.681357
# 2           13.71498
# 3           18.35104
# 4          12.200108
# ..               ...
# 56          8.563728
# 57          7.686345
# 58         13.763095
# 59         10.407801
# 60         15.786017
#
# [61 rows x 6 columns]
#                                        Library_Region  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 1   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2   http://dati.beniculturali.it/mibact/luoghi/res...      4
# 3   http://dati.beniculturali.it/mibact/luoghi/res...      5
# 4   http://dati.beniculturali.it/mibact/luoghi/res...      2
# 5   http://dati.beniculturali.it/mibact/luoghi/res...     19
# 6   http://dati.beniculturali.it/mibact/luoghi/res...      2
# 7   http://dati.beniculturali.it/mibact/luoghi/res...      4
# 8   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 9   http://dati.beniculturali.it/mibact/luoghi/res...      4
# 10  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 11  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 12  http://dati.beniculturali.it/mibact/luoghi/res...      8
# 13  http://dati.beniculturali.it/mibact/luoghi/res...      6
# 14                                              Total     61
#                                          Library_City  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 1   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 3   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 4   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 5   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 6   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 7   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 8   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 9   http://dati.beniculturali.it/mibact/luoghi/res...      1
# 10  http://dati.beniculturali.it/mibact/luoghi/res...      5
# 11  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 12  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 13  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 14  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 15  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 16  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 17  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 18  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 19  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 20  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 21  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 22  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 23  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 24  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 25  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 26  http://dati.beniculturali.it/mibact/luoghi/res...     10
# 27  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 28  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 29  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 30  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 31  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 32  http://dati.beniculturali.it/mibact/luoghi/res...      3
# 33  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 34  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 35  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 36  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 37  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 38                                              Total     61

# %%
""" This query was done to idenfity in the library dataframe a specific typology of libraries ("Biblioteche statali") for a better understing of the composition of the dataset"""

#Exploratory query for identifying the Mibact libraries classified as dctype:"Biblioteca Statale"
query_2bis = """
 PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
 PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
 PREFIX cis: <http://dati.beniculturali.it/cis/>
 PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>
 PREFIX dc: <http://purl.org/dc/elements/1.1/>
 PREFIX geo1: <http://www.w3.org/2003/01/geo/wgs84_pos#>

 SELECT ?library ?librarylabel ?libraryCity ?libraryRegion ?librarylatitude ?librarylongitude 
 WHERE {

   # ?library dc:type "Biblioteca Statale" .
   # ?library a cis:CulturalInstituteOrSite.
   # ?library rdfs:label ?librarylabel.
   # ?library cis:hasSite ?librarysite.
   # ?librarysite cis:siteAddress ?libraryAddress.
   # ?libraryAddress clvapit:hasRegion ?libraryRegion.
   # ?libraryAddress clvapit:hasCity ?libraryCity.
   # ?library geo1:lat ?librarylatitude.
   # ?library geo1:long ?librarylongitude.
 } 
  

"""

# Perform the query
results = g.query(query_2bis)

#Mibact Libraries Dataframe
data_Libraries = []
for row in results:
    data_Libraries.append({'Library_ID': str(row['library']), 'Library_Name': str(row['librarylabel']),'Library_City': str(row['libraryCity']), 'Library_Region': str(row['libraryRegion']),'Library_Latitude': str(row['librarylatitude']), 'Library_Longitude': str(row['librarylongitude'])})
df_Libraries = pd.DataFrame(data_Libraries)

# List of IDs to remove that are not libraries
IDs_to_remove=["http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102857",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102889",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102891",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/101975",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102879",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102917",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102858",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102876",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102853",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/110257",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102864",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/102855"]

# Find rows to remove in Library_ID
rows_to_remove = df_Libraries[df_Libraries['Library_ID'].isin(IDs_to_remove)].index
Mibact_libraries_df = df_Libraries.drop(rows_to_remove)
Mibact_libraries_df.reset_index(drop=True, inplace=True)

#Displaying Mibact Libraries Dataframe
display(Mibact_libraries_df)


# # #CSV files from Mibact Libraries Dataframe
# csv_file_Mibact_libraries = "Mibact_Libraries_Luoghi_Cultura.csv"
# Mibact_libraries_df.to_csv(csv_file_Mibact_libraries, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_Mibact_libraries}")
# Out:
#                                            Library_ID  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...
# 1   http://dati.beniculturali.it/mibact/luoghi/res...
# 2   http://dati.beniculturali.it/mibact/luoghi/res...
# 3   http://dati.beniculturali.it/mibact/luoghi/res...
# 4   http://dati.beniculturali.it/mibact/luoghi/res...
# 5   http://dati.beniculturali.it/mibact/luoghi/res...
# 6   http://dati.beniculturali.it/mibact/luoghi/res...
# 7   http://dati.beniculturali.it/mibact/luoghi/res...
# 8   http://dati.beniculturali.it/mibact/luoghi/res...
# 9   http://dati.beniculturali.it/mibact/luoghi/res...
# 10  http://dati.beniculturali.it/mibact/luoghi/res...
# 11  http://dati.beniculturali.it/mibact/luoghi/res...
# 12  http://dati.beniculturali.it/mibact/luoghi/res...
# 13  http://dati.beniculturali.it/mibact/luoghi/res...
# 14  http://dati.beniculturali.it/mibact/luoghi/res...
# 15  http://dati.beniculturali.it/mibact/luoghi/res...
# 16  http://dati.beniculturali.it/mibact/luoghi/res...
# 17  http://dati.beniculturali.it/mibact/luoghi/res...
# 18  http://dati.beniculturali.it/mibact/luoghi/res...
# 19  http://dati.beniculturali.it/mibact/luoghi/res...
# 20  http://dati.beniculturali.it/mibact/luoghi/res...
# 21  http://dati.beniculturali.it/mibact/luoghi/res...
# 22  http://dati.beniculturali.it/mibact/luoghi/res...
# 23  http://dati.beniculturali.it/mibact/luoghi/res...
# 24  http://dati.beniculturali.it/mibact/luoghi/res...
# 25  http://dati.beniculturali.it/mibact/luoghi/res...
# 26  http://dati.beniculturali.it/mibact/luoghi/res...
# 27  http://dati.beniculturali.it/mibact/luoghi/res...
# 28  http://dati.beniculturali.it/mibact/luoghi/res...
# 29  http://dati.beniculturali.it/mibact/luoghi/res...
# 30  http://dati.beniculturali.it/mibact/luoghi/res...
# 31  http://dati.beniculturali.it/mibact/luoghi/res...
# 32  http://dati.beniculturali.it/mibact/luoghi/res...
# 33  http://dati.beniculturali.it/mibact/luoghi/res...
# 34  http://dati.beniculturali.it/mibact/luoghi/res...
# 35  http://dati.beniculturali.it/mibact/luoghi/res...
# 36  http://dati.beniculturali.it/mibact/luoghi/res...
# 37  http://dati.beniculturali.it/mibact/luoghi/res...
# 38  http://dati.beniculturali.it/mibact/luoghi/res...
# 39  http://dati.beniculturali.it/mibact/luoghi/res...
# 40  http://dati.beniculturali.it/mibact/luoghi/res...
# 41  http://dati.beniculturali.it/mibact/luoghi/res...
# 42  http://dati.beniculturali.it/mibact/luoghi/res...
# 43  http://dati.beniculturali.it/mibact/luoghi/res...
# 44  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                          Library_Name  \
# 0   Biblioteca nazionale Marciana - Sale monumenta...
# 1                     Biblioteca Nazionale di Cosenza
# 2                              Biblioteca Casanatense
# 3                         Biblioteca Statale di Lucca
# 4                              Biblioteca Riccardiana
# 5                      Biblioteca Medicea Laurenziana
# 6   Biblioteca Statale del Monumento Nazionale di ...
# 7                   Biblioteca Medica Statale di Roma
# 8                  Biblioteca Universitaria di Padova
# 9                      Biblioteca statale di Macerata
# 10                           Biblioteca Vallicelliana
# 11  Biblioteca Statale del Monumento Nazionale di ...
# 12               Biblioteca Universitaria di Cagliari
# 13                                Biblioteca Angelica
# 14                 Biblioteca statale Antonio Baldini
# 15  Biblioteca Statale del Monumento Nazionale di ...
# 16                      Biblioteca statale di Cremona
# 17       Biblioteca di storia moderna e contemporanea
# 18  Complesso monumentale della Pilotta - Bibliote...
# 19  Biblioteca Statale Annessa al Monumento Nazion...
# 20  Pinacoteca di Brera - Biblioteca Nazionale Bra...
# 21              Biblioteca nazionale centrale di Roma
# 22              Biblioteca Universitaria Alessandrina
# 23  Biblioteca Statale del Monumento Nazionale di ...
# 24  Biblioteca Statale del Monumento nazionale di ...
# 25             Biblioteca statale Isontina di Gorizia
# 26                 Biblioteca Universitaria di Genova
# 27                  Biblioteca Universitaria di Pavia
# 28  Biblioteca Statale del Monumento Nazionale di ...
# 29                 Biblioteca Universitaria di Napoli
# 30                      Biblioteca nazionale Marciana
# 31  Biblioteca Statale del monumento nazionale di ...
# 32  Biblioteca Nazionale di Napoli "Vittorio Emanu...
# 33  Biblioteca statale del monumento nazionale del...
# 34  Gallerie estensi - Biblioteca estense universi...
# 35           Biblioteca Nazionale Centrale di Firenze
# 36  Biblioteca statale del Monumento nazionale di ...
# 37                   Biblioteca universitaria di Pisa
# 38       Biblioteca nazionale universitaria di Torino
# 39                            Biblioteca Marucelliana
# 40                Biblioteca Universitaria di Sassari
# 41                     Musei Reali - Biblioteca Reale
# 42         Biblioteca Statale Stelio Crise di Trieste
# 43  San Matteo - Sede distaccata Biblioteca Univer...
# 44                    Biblioteca Nazionale di Potenza
#
#                                          Library_City  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...
# 1   http://dati.beniculturali.it/mibact/luoghi/res...
# 2   http://dati.beniculturali.it/mibact/luoghi/res...
# 3   http://dati.beniculturali.it/mibact/luoghi/res...
# 4   http://dati.beniculturali.it/mibact/luoghi/res...
# 5   http://dati.beniculturali.it/mibact/luoghi/res...
# 6   http://dati.beniculturali.it/mibact/luoghi/res...
# 7   http://dati.beniculturali.it/mibact/luoghi/res...
# 8   http://dati.beniculturali.it/mibact/luoghi/res...
# 9   http://dati.beniculturali.it/mibact/luoghi/res...
# 10  http://dati.beniculturali.it/mibact/luoghi/res...
# 11  http://dati.beniculturali.it/mibact/luoghi/res...
# 12  http://dati.beniculturali.it/mibact/luoghi/res...
# 13  http://dati.beniculturali.it/mibact/luoghi/res...
# 14  http://dati.beniculturali.it/mibact/luoghi/res...
# 15  http://dati.beniculturali.it/mibact/luoghi/res...
# 16  http://dati.beniculturali.it/mibact/luoghi/res...
# 17  http://dati.beniculturali.it/mibact/luoghi/res...
# 18  http://dati.beniculturali.it/mibact/luoghi/res...
# 19  http://dati.beniculturali.it/mibact/luoghi/res...
# 20  http://dati.beniculturali.it/mibact/luoghi/res...
# 21  http://dati.beniculturali.it/mibact/luoghi/res...
# 22  http://dati.beniculturali.it/mibact/luoghi/res...
# 23  http://dati.beniculturali.it/mibact/luoghi/res...
# 24  http://dati.beniculturali.it/mibact/luoghi/res...
# 25  http://dati.beniculturali.it/mibact/luoghi/res...
# 26  http://dati.beniculturali.it/mibact/luoghi/res...
# 27  http://dati.beniculturali.it/mibact/luoghi/res...
# 28  http://dati.beniculturali.it/mibact/luoghi/res...
# 29  http://dati.beniculturali.it/mibact/luoghi/res...
# 30  http://dati.beniculturali.it/mibact/luoghi/res...
# 31  http://dati.beniculturali.it/mibact/luoghi/res...
# 32  http://dati.beniculturali.it/mibact/luoghi/res...
# 33  http://dati.beniculturali.it/mibact/luoghi/res...
# 34  http://dati.beniculturali.it/mibact/luoghi/res...
# 35  http://dati.beniculturali.it/mibact/luoghi/res...
# 36  http://dati.beniculturali.it/mibact/luoghi/res...
# 37  http://dati.beniculturali.it/mibact/luoghi/res...
# 38  http://dati.beniculturali.it/mibact/luoghi/res...
# 39  http://dati.beniculturali.it/mibact/luoghi/res...
# 40  http://dati.beniculturali.it/mibact/luoghi/res...
# 41  http://dati.beniculturali.it/mibact/luoghi/res...
# 42  http://dati.beniculturali.it/mibact/luoghi/res...
# 43  http://dati.beniculturali.it/mibact/luoghi/res...
# 44  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                        Library_Region Library_Latitude  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...        45.434067
# 1   http://dati.beniculturali.it/mibact/luoghi/res...        39.288624
# 2   http://dati.beniculturali.it/mibact/luoghi/res...        41.898148
# 3   http://dati.beniculturali.it/mibact/luoghi/res...          43.8449
# 4   http://dati.beniculturali.it/mibact/luoghi/res...         43.77558
# 5   http://dati.beniculturali.it/mibact/luoghi/res...        43.774815
# 6   http://dati.beniculturali.it/mibact/luoghi/res...         41.76406
# 7   http://dati.beniculturali.it/mibact/luoghi/res...         0.040255
# 8   http://dati.beniculturali.it/mibact/luoghi/res...         45.40711
# 9   http://dati.beniculturali.it/mibact/luoghi/res...         43.30105
# 10  http://dati.beniculturali.it/mibact/luoghi/res...        41.898186
# 11  http://dati.beniculturali.it/mibact/luoghi/res...        41.925537
# 12  http://dati.beniculturali.it/mibact/luoghi/res...        39.217236
# 13  http://dati.beniculturali.it/mibact/luoghi/res...          41.9007
# 14  http://dati.beniculturali.it/mibact/luoghi/res...         41.91954
# 15  http://dati.beniculturali.it/mibact/luoghi/res...        41.490738
# 16  http://dati.beniculturali.it/mibact/luoghi/res...        45.138042
# 17  http://dati.beniculturali.it/mibact/luoghi/res...        41.894035
# 18  http://dati.beniculturali.it/mibact/luoghi/res...         44.80498
# 19  http://dati.beniculturali.it/mibact/luoghi/res...        41.787067
# 20  http://dati.beniculturali.it/mibact/luoghi/res...        45.471947
# 21  http://dati.beniculturali.it/mibact/luoghi/res...        41.906784
# 22  http://dati.beniculturali.it/mibact/luoghi/res...         41.90336
# 23  http://dati.beniculturali.it/mibact/luoghi/res...         45.36541
# 24  http://dati.beniculturali.it/mibact/luoghi/res...         40.91894
# 25  http://dati.beniculturali.it/mibact/luoghi/res...        45.946304
# 26  http://dati.beniculturali.it/mibact/luoghi/res...         44.41616
# 27  http://dati.beniculturali.it/mibact/luoghi/res...         45.18673
# 28  http://dati.beniculturali.it/mibact/luoghi/res...        45.395912
# 29  http://dati.beniculturali.it/mibact/luoghi/res...        40.847164
# 30  http://dati.beniculturali.it/mibact/luoghi/res...         45.43377
# 31  http://dati.beniculturali.it/mibact/luoghi/res...        42.207504
# 32  http://dati.beniculturali.it/mibact/luoghi/res...         40.83619
# 33  http://dati.beniculturali.it/mibact/luoghi/res...         40.68232
# 34  http://dati.beniculturali.it/mibact/luoghi/res...         44.64811
# 35  http://dati.beniculturali.it/mibact/luoghi/res...        43.766922
# 36  http://dati.beniculturali.it/mibact/luoghi/res...        41.667736
# 37  http://dati.beniculturali.it/mibact/luoghi/res...          43.7152
# 38  http://dati.beniculturali.it/mibact/luoghi/res...        45.068684
# 39  http://dati.beniculturali.it/mibact/luoghi/res...        43.771034
# 40  http://dati.beniculturali.it/mibact/luoghi/res...        40.722702
# 41  http://dati.beniculturali.it/mibact/luoghi/res...         45.07285
# 42  http://dati.beniculturali.it/mibact/luoghi/res...         45.64559
# 43  http://dati.beniculturali.it/mibact/luoghi/res...          43.7152
# 44  http://dati.beniculturali.it/mibact/luoghi/res...        40.634987
#
#    Library_Longitude
# 0          12.334472
# 1           16.26098
# 2          12.479639
# 3          10.501189
# 4          11.255349
# 5          11.254537
# 6           13.37067
# 7          -0.010042
# 8          11.880526
# 9          13.448922
# 10         12.469432
# 11         13.104736
# 12          9.115117
# 13         12.474194
# 14          12.48609
# 15          13.82541
# 16         10.021977
# 17         12.478293
# 18           10.3259
# 19         12.667435
# 20          9.187837
# 21         12.504962
# 22         12.515426
# 23          11.73515
# 24         14.749575
# 25          13.62364
# 26          8.924084
# 27          9.155909
# 28         11.879983
# 29          14.25703
# 30         12.338424
# 31         12.729794
# 32         14.249669
# 33         14.691221
# 34         10.921424
# 35         11.262235
# 36         13.436525
# 37         10.407801
# 38           7.68633
# 39            11.248
# 40          8.563728
# 41          7.686345
# 42         13.763095
# 43         10.407801
# 44         15.786017

# %%
#	Exploratory Query for identifying the museums IDs, Names, Cities and Regions

query_3 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX cis: <http://dati.beniculturali.it/cis/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>

SELECT ?museum ?museumlabel ?museumCity ?museumRegion
WHERE {
  # ?museum rdf:type cis:CulturalInstituteOrSite .
  # ?museum dc:type "Museo, Galleria e/o raccolta".
  # ?museum rdfs:label ?museumlabel .
  # ?museum cis:hasSite ?museumSite.
  # ?museumSite cis:siteAddress ?museumAddress.
  # ?museumAddress clvapit:hasRegion ?museumRegion.
  # ?museumAddress clvapit:hasCity ?museumCity.

}
"""


# Perform the query
results = g.query(query_3)

#Museums DataFrame
data_Museums = []
for row in results:
    data_Museums.append({'Museum_ID': str(row['museum']), 'Museum_Name': str(row['museumlabel']), 'Museum_City': str(row['museumCity']), 'Museum_Region': str(row['museumRegion'])})

df_Museums = pd.DataFrame(data_Museums)

"""In this phase we decided to Enrich Museums Dataframe with other Museums entities from OtherPlaces dataframe in order to not leave out any entities 
that can be considered as a Museum"""

#filtering OtherPlaces dataframe according their names that contains museum(s) word
df_other_places = pd.DataFrame(data_OtherPlaces)
filtered_Other_Places_df = df_OtherPlaces[df_OtherPlaces['OtherPlace_Name'].str.contains('muse', case=False, na=False)]

#Renaming columns of new filtered Museum Dataframe
df_filtered_museums=filtered_Other_Places_df.rename(columns={
    'OtherPlace_ID': 'Museum_ID',
    'OtherPlace_Name': 'Museum_Name',
    'OtherPlace_City': 'Museum_City',
    'OtherPlace_Region': 'Museum_Region'
})

#Dropping "OtherPlace_Type column which is not needed in the new filtered Museum Dataframe"
df_filtered_museums = df_filtered_museums.drop(columns=['OtherPlace_Type'])


#Mergin the previous Museum Dataframe with the filtered Museum Dataframes to create a new Dataframe with all museum entities
df_Museums = pd.DataFrame(data_Museums)
df_museums_complete= pd.concat([df_filtered_museums, df_Museums], ignore_index=True)

#New dataframes for counting museum cities and regions
museum_region_counts_complete = df_museums_complete.groupby('Museum_Region').size().reset_index(name='Count')
museum_city_counts_complete = df_museums_complete.groupby('Museum_City').size().reset_index(name='Count')

#Displaying all dataframes for Museum entities
display(df_museums_complete)
display(museum_region_counts_complete)
display(museum_city_counts_complete)

# #CSV files for Museums from the above Dataframes
# csv_file_museums_complete = "Museums_complete.csv"
# df_museums_complete.to_csv(csv_file_museums_complete, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums_complete}")

# csv_file_museums_region_count_complete = "Museums_region_count_complete.csv"
# museum_region_counts_complete.to_csv(csv_file_museums_region_count_complete, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums_region_count_complete}")

# csv_file_museums_city_count_complete = "Museums_city_count_complete.csv"
# museum_city_counts_complete.to_csv(csv_file_museums_city_count_complete, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums_city_count_complete}")
# Out:
#                                               Museum_ID  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 4888  http://dati.beniculturali.it/mibact/luoghi/res...
# 4889  http://dati.beniculturali.it/mibact/luoghi/res...
# 4890  http://dati.beniculturali.it/mibact/luoghi/res...
# 4891  http://dati.beniculturali.it/mibact/luoghi/res...
# 4892  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                             Museum_Name  \
# 0                             Museo Annibale Di Francia
# 1                       Museo della Fondazione Whitaker
# 2     Musei sistini del Piceno - Museo di arte sacra...
# 3             Parco Poesia Pascoli - Museo Casa Pascoli
# 4     Ecomuseo della Montagna Pistoiese − Insediamen...
# ...                                                 ...
# 4888                                      Museo Fortuny
# 4889                       Museo del presepio di Giarre
# 4890                      Pinacoteca e Museo delle Arti
# 4891                    Pinacoteca dei Padri Cappuccini
# 4892                Museo civico archeologico di Padria
#
#                                             Museum_City  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 4888  http://dati.beniculturali.it/mibact/luoghi/res...
# 4889  http://dati.beniculturali.it/mibact/luoghi/res...
# 4890  http://dati.beniculturali.it/mibact/luoghi/res...
# 4891  http://dati.beniculturali.it/mibact/luoghi/res...
# 4892  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                           Museum_Region
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 4888  http://dati.beniculturali.it/mibact/luoghi/res...
# 4889  http://dati.beniculturali.it/mibact/luoghi/res...
# 4890  http://dati.beniculturali.it/mibact/luoghi/res...
# 4891  http://dati.beniculturali.it/mibact/luoghi/res...
# 4892  http://dati.beniculturali.it/mibact/luoghi/res...
#
# [4893 rows x 4 columns]
#                                         Museum_Region  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...    130
# 1   http://dati.beniculturali.it/mibact/luoghi/res...     63
# 2   http://dati.beniculturali.it/mibact/luoghi/res...    215
# 3   http://dati.beniculturali.it/mibact/luoghi/res...    236
# 4   http://dati.beniculturali.it/mibact/luoghi/res...    499
# 5   http://dati.beniculturali.it/mibact/luoghi/res...    157
# 6   http://dati.beniculturali.it/mibact/luoghi/res...    340
# 7   http://dati.beniculturali.it/mibact/luoghi/res...    180
# 8   http://dati.beniculturali.it/mibact/luoghi/res...    473
# 9   http://dati.beniculturali.it/mibact/luoghi/res...    297
# 10  http://dati.beniculturali.it/mibact/luoghi/res...     33
# 11  http://dati.beniculturali.it/mibact/luoghi/res...    543
# 12  http://dati.beniculturali.it/mibact/luoghi/res...    203
# 13  http://dati.beniculturali.it/mibact/luoghi/res...    169
# 14  http://dati.beniculturali.it/mibact/luoghi/res...    224
# 15  http://dati.beniculturali.it/mibact/luoghi/res...    558
# 16  http://dati.beniculturali.it/mibact/luoghi/res...    146
# 17  http://dati.beniculturali.it/mibact/luoghi/res...    196
# 18  http://dati.beniculturali.it/mibact/luoghi/res...     50
# 19  http://dati.beniculturali.it/mibact/luoghi/res...    181
#                                             Museum_City  Count
# 0     http://dati.beniculturali.it/mibact/luoghi/res...      1
# 1     http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2     http://dati.beniculturali.it/mibact/luoghi/res...      2
# 3     http://dati.beniculturali.it/mibact/luoghi/res...      1
# 4     http://dati.beniculturali.it/mibact/luoghi/res...      1
# ...                                                 ...    ...
# 2377  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2378  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2379  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2380  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 2381  http://dati.beniculturali.it/mibact/luoghi/res...      1
#
# [2382 rows x 2 columns]

# %%
#Exploratory Query for identifying the Archive IDs, Names, Cities and Regions

query_4 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX cis: <http://dati.beniculturali.it/cis/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>

SELECT ?archive ?archivelabel ?archiveCity ?archiveRegion
WHERE {

   {
    # ?archive dc:type "Archivio di Stato".
  }
  UNION
  {
   # ?archive dc:type "Archivio".
  }


  # ?archive rdf:type cis:CulturalInstituteOrSite .
  # ?archive rdfs:label ?archivelabel .
  # ?archive cis:hasSite ?archiveSite.
  # ?archiveSite cis:siteAddress ?archiveAddress.
  # ?archiveAddress clvapit:hasRegion ?archiveRegion.
  # ?archiveAddress clvapit:hasCity ?archiveCity.
}
"""


# Perform the query
results = g.query(query_4)


#Archives Dataframe
data_Archives = []
for row in results:
    data_Archives.append({'Archive_ID': str(row['archive']), 'Archive_Name': str(row['archivelabel']), 'Archive_City': str(row['archiveCity']),'Archive_Region': str(row['archiveRegion']) })
df_archives = pd.DataFrame(data_Archives)

#Dataframes for counting archives by their city and region
archive_region_counts = df_archives.groupby('Archive_Region').size().reset_index(name='Count')
archive_city_counts = df_archives.groupby('Archive_City').size().reset_index(name='Count')

#Displaying all dataframes for Archives entities
display(df_archives)
display(archive_region_counts)
display(archive_city_counts)


#CSV from all Dataframes for Archives
# csv_file_archives = "Archives_Luoghi_Cultura.csv"
# df_archives.to_csv(csv_file_archives, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_archives}")

# csv_file_archives_region_count = "Archives_region_count_Luoghi_Cultura.csv"
# archive_region_counts.to_csv(csv_file_archives_region_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_archives_region_count}")


# csv_file_archives_city_count = "Archives_city_count_Luoghi_Cultura.csv"
# archive_city_counts.to_csv(csv_file_archives_city_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_archives_city_count}")
# Out:
#                                             Archive_ID  \
# 0    http://dati.beniculturali.it/mibact/luoghi/res...
# 1    http://dati.beniculturali.it/mibact/luoghi/res...
# 2    http://dati.beniculturali.it/mibact/luoghi/res...
# 3    http://dati.beniculturali.it/mibact/luoghi/res...
# 4    http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                 ...
# 148  http://dati.beniculturali.it/mibact/luoghi/res...
# 149  http://dati.beniculturali.it/mibact/luoghi/res...
# 150  http://dati.beniculturali.it/mibact/luoghi/res...
# 151  http://dati.beniculturali.it/mibact/luoghi/res...
# 152  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                           Archive_Name  \
# 0                   Archivio di Stato di Reggio Emilia
# 1                          Archivio di Stato di Trento
# 2       Archivio di Stato di Bologna, Sezione di Imola
# 3                        Archivio centrale dello Stato
# 4    Soprintendenza Archivistica della Sicilia - Ar...
# ..                                                 ...
# 148                        Archivio di Stato di Varese
# 149                                         Casa Zegna
# 150                     Collezione storica ATC Bologna
# 151               Raccolta Archivio Toraldo di Francia
# 152                               Fondazione Memofonte
#
#                                           Archive_City  \
# 0    http://dati.beniculturali.it/mibact/luoghi/res...
# 1    http://dati.beniculturali.it/mibact/luoghi/res...
# 2    http://dati.beniculturali.it/mibact/luoghi/res...
# 3    http://dati.beniculturali.it/mibact/luoghi/res...
# 4    http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                 ...
# 148  http://dati.beniculturali.it/mibact/luoghi/res...
# 149  http://dati.beniculturali.it/mibact/luoghi/res...
# 150  http://dati.beniculturali.it/mibact/luoghi/res...
# 151  http://dati.beniculturali.it/mibact/luoghi/res...
# 152  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                         Archive_Region
# 0    http://dati.beniculturali.it/mibact/luoghi/res...
# 1    http://dati.beniculturali.it/mibact/luoghi/res...
# 2    http://dati.beniculturali.it/mibact/luoghi/res...
# 3    http://dati.beniculturali.it/mibact/luoghi/res...
# 4    http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                 ...
# 148  http://dati.beniculturali.it/mibact/luoghi/res...
# 149  http://dati.beniculturali.it/mibact/luoghi/res...
# 150  http://dati.beniculturali.it/mibact/luoghi/res...
# 151  http://dati.beniculturali.it/mibact/luoghi/res...
# 152  http://dati.beniculturali.it/mibact/luoghi/res...
#
# [153 rows x 4 columns]
#                                        Archive_Region  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...      7
# 1   http://dati.beniculturali.it/mibact/luoghi/res...      3
# 2   http://dati.beniculturali.it/mibact/luoghi/res...      9
# 3   http://dati.beniculturali.it/mibact/luoghi/res...      5
# 4   http://dati.beniculturali.it/mibact/luoghi/res...     13
# 5   http://dati.beniculturali.it/mibact/luoghi/res...      5
# 6   http://dati.beniculturali.it/mibact/luoghi/res...      7
# 7   http://dati.beniculturali.it/mibact/luoghi/res...      8
# 8   http://dati.beniculturali.it/mibact/luoghi/res...     10
# 9   http://dati.beniculturali.it/mibact/luoghi/res...     13
# 10  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 11  http://dati.beniculturali.it/mibact/luoghi/res...     11
# 12  http://dati.beniculturali.it/mibact/luoghi/res...      7
# 13  http://dati.beniculturali.it/mibact/luoghi/res...      4
# 14  http://dati.beniculturali.it/mibact/luoghi/res...     16
# 15  http://dati.beniculturali.it/mibact/luoghi/res...     15
# 16  http://dati.beniculturali.it/mibact/luoghi/res...      2
# 17  http://dati.beniculturali.it/mibact/luoghi/res...      6
# 18  http://dati.beniculturali.it/mibact/luoghi/res...     10
#                                           Archive_City  Count
# 0    http://dati.beniculturali.it/mibact/luoghi/res...      1
# 1    http://dati.beniculturali.it/mibact/luoghi/res...      2
# 2    http://dati.beniculturali.it/mibact/luoghi/res...      1
# 3    http://dati.beniculturali.it/mibact/luoghi/res...      1
# 4    http://dati.beniculturali.it/mibact/luoghi/res...      4
# ..                                                 ...    ...
# 130  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 131  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 132  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 133  http://dati.beniculturali.it/mibact/luoghi/res...      1
# 134  http://dati.beniculturali.it/mibact/luoghi/res...      1
#
# [135 rows x 2 columns]

# %%
""" Another step of the dataset analysis was to understand if there were entities with a free entry or a ticket to pay, particularly with a focus related to museums, libraries and 
 archives. This aspect was important in order to understand the The level of affordability from an economic point of view of people to different institutions."""


#		Exploratory query for defining entities and if they have a ticket cost/entry price or if they are free 
query_5 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX cis: <http://dati.beniculturali.it/cis/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>
PREFIX potapit: <https://w3id.org/italia/onto/POT/>


SELECT ?Entity ?EntryPrice
WHERE {
  # ?Entity rdf:type potapit:PriceSpecification.
  # ?Entity potapit:hasCurrencyValue ?EntryPrice.

}
"""

# Perform the query
results = g.query(query_5)


#Dataframe for All Entities and the Ticket Prices or Free Entry 
data_Prices = []
for row in results:
    data_Prices.append({'Entity_ID': str(row['Entity']), 'Entry_Price': str(row['EntryPrice'])})
df_Ticket_Free_Entry_Prices = pd.DataFrame(data_Prices)

#Datarames dividing entities with free entry and entities with a ticket cost
df_free_entry = df_Ticket_Free_Entry_Prices[df_Ticket_Free_Entry_Prices['Entry_Price'].str.contains('Gratuito', case=False, na=False)]
df_free_entry = df_free_entry.reset_index(drop=True)
df_ticket_cost = df_Ticket_Free_Entry_Prices[df_Ticket_Free_Entry_Prices['Entry_Price'].str.match(r'^\d+(,\d+)?(\.\d+)?$', na=False)]
df_ticket_cost = df_ticket_cost.reset_index(drop=True)

#Displaying dataframes of entities with a ticket cost or a free entry all toghether and separated dataframes for entities with ticket cost and free entry
display(df_Ticket_Free_Entry_Prices)
display(df_free_entry)
display(df_ticket_cost)


# #CSV files from all Dataframes Entities with their Ticket Cost/Entry Price
# csv_Entities_Ticket_Entry_Prices = "Entities_Ticket_Prices_Free_Entry.csv"
# df_Ticket_Free_Entry_Prices.to_csv(csv_Entities_Ticket_Entry_Prices, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_Entities_Ticket_Entry_Prices}")

# csv_Entities_Free_Entry = "Entities_Free_Entry.csv"
# df_free_entry.to_csv(csv_Entities_Free_Entry, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_Entities_Free_Entry}")

# csv_Entities_Ticket_Cost = "Entities_Ticket_Cost.csv"
# df_ticket_cost.to_csv(csv_Entities_Ticket_Cost, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_Entities_Ticket_Cost}")
# Out:
#                                               Entity_ID Entry_Price
# 0     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 1     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 2     http://dati.beniculturali.it/mibact/luoghi/res...         4.0
# 3     http://dati.beniculturali.it/mibact/luoghi/res...        3,50
# 4     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# ...                                                 ...         ...
# 5072  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
# 5073  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 5074  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 5075  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
# 5076  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
#
# [5077 rows x 2 columns]
#                                               Entity_ID Entry_Price
# 0     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 1     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 2     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 3     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 4     http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# ...                                                 ...         ...
# 2161  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 2162  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 2163  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 2164  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
# 2165  http://dati.beniculturali.it/mibact/luoghi/res...    Gratuito
#
# [2166 rows x 2 columns]
#                                               Entity_ID Entry_Price
# 0     http://dati.beniculturali.it/mibact/luoghi/res...         4.0
# 1     http://dati.beniculturali.it/mibact/luoghi/res...        3,50
# 2     http://dati.beniculturali.it/mibact/luoghi/res...        3,00
# 3     http://dati.beniculturali.it/mibact/luoghi/res...        4,00
# 4     http://dati.beniculturali.it/mibact/luoghi/res...        6,00
# ...                                                 ...         ...
# 2906  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
# 2907  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
# 2908  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
# 2909  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
# 2910  http://dati.beniculturali.it/mibact/luoghi/res...        5,00
#
# [2911 rows x 2 columns]

# %%
""" In this phase all the museums entitites of the Museum dataframe were compared with the entities in the ticket cost and free entry dataframes in order to check how many museums
were free and how many had a ticket cost (if any)"""

#CHECKING FOR FREE ENTRY MUSEUMS

#Script for extracting IDs from Dataframe of Entites with Free Entry
import re
def extract_id(entity_id):
    match = re.search(r'/(\d+)_', entity_id)
    if match:
        return match.group(1)  
    return None  

numeric_ids = df_free_entry['Entity_ID'].apply(extract_id).tolist()

#Script for checking if any Museum Ids in Museums Dataframe match with Ids in numeric_ids list made from free enty entities Dataframe
def check_id_in_museum_id(museum_id):
    for numeric_id in numeric_ids:
        if numeric_id in museum_id:
            return 'Free Entry'
    return None

#Dataframes of Museums with free entry cost and their number for each region and city
df_museums_complete['Ticket_Cost'] = df_museums_complete['Museum_ID'].apply(check_id_in_museum_id)
df_museum_free_entry_cost = df_museums_complete[df_museums_complete['Ticket_Cost'] == 'Free Entry'].reset_index(drop=True)
df_museum_free_entry_region_counts = df_museum_free_entry_cost.groupby(['Museum_Region', 'Ticket_Cost']).size().reset_index(name='Count')
df_museum_free_entry_city_counts = df_museum_free_entry_cost.groupby(['Museum_City', 'Ticket_Cost']).size().reset_index(name='Count')

#Displaying dataframes for Museum free entry cost entities, their city and region count
display(df_museum_free_entry_cost)
display(df_museum_free_entry_region_counts)
display(df_museum_free_entry_city_counts)

# #CSV of all above Dataframes
# csv_file_museums_free_entry_cost = "Museums_Free_Entry_cost.csv"
# df_museum_free_entry_cost.to_csv(csv_file_museums_free_entry_cost, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums_free_entry_cost}")

# csv_file_museums_free_entry_region_count = "Museums_Free_Entry_region_count.csv"
# df_museum_free_entry_region_counts.to_csv(csv_file_museums_free_entry_region_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums_free_entry_region_count}")

# csv_file_museums_free_entry_city_count = "Museums_Free_Entry_city_count.csv"
# df_museum_free_entry_city_counts.to_csv(csv_file_museums_free_entry_city_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums_free_entry_city_count}")
# Out:
#                                               Museum_ID  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1445  http://dati.beniculturali.it/mibact/luoghi/res...
# 1446  http://dati.beniculturali.it/mibact/luoghi/res...
# 1447  http://dati.beniculturali.it/mibact/luoghi/res...
# 1448  http://dati.beniculturali.it/mibact/luoghi/res...
# 1449  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                             Museum_Name  \
# 0     Ecomuseo della Montagna Pistoiese − Insediamen...
# 1                       Museo armi antiche Fosco Baboni
# 2              Piccolo museo delle anime del Purgatorio
# 3                    Museo del Convento di Santa Chiara
# 4                      Castello normanno - Museo civico
# ...                                                 ...
# 1445            Museo del bracconaggio e delle trappole
# 1446  Casa museo "Joe Petrosino" Padula-New York-Pal...
# 1447        Mostra archeologica permanente "Divi & Dei"
# 1448             Museo della civiltà contadina di Sefro
# 1449      Museo parrocchiale d’arte sacra "Don G. Polo"
#
#                                             Museum_City  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1445  http://dati.beniculturali.it/mibact/luoghi/res...
# 1446  http://dati.beniculturali.it/mibact/luoghi/res...
# 1447  http://dati.beniculturali.it/mibact/luoghi/res...
# 1448  http://dati.beniculturali.it/mibact/luoghi/res...
# 1449  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                           Museum_Region Ticket_Cost
# 0     http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 1     http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 2     http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 3     http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 4     http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# ...                                                 ...         ...
# 1445  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 1446  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 1447  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 1448  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 1449  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
#
# [1450 rows x 5 columns]
#                                         Museum_Region Ticket_Cost  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     27
# 1   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 2   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     26
# 3   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry    165
# 4   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry    349
# 5   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry    109
# 6   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry    195
# 7   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry    107
# 8   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry    159
# 9   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     69
# 10  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 11  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     54
# 12  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     32
# 13  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     20
# 14  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     41
# 15  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     49
# 16  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      8
# 17  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 18  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      9
# 19  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     10
#                                            Museum_City Ticket_Cost  Count
# 0    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 1    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      3
# 2    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 3    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 4    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# ..                                                 ...         ...    ...
# 883  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 884  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 885  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 886  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 887  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
#
# [888 rows x 3 columns]

# %%
#CHECKING FOR MUSEUMS WITH A TICKET COST

#Script for extracting IDs from Dataframe of Entites with a ticket cost entry

import re
def extract_id(entity_id):
    match = re.search(r'/(\d+)_', entity_id)
    if match:
        numeric_id = match.group(1)  
        price = df_ticket_cost.loc[df_ticket_cost['Entity_ID'] == entity_id, 'Entry_Price'].iloc[0]  
        return (numeric_id, price)  
    return None  
numeric_ids_with_prices= df_ticket_cost['Entity_ID'].apply(extract_id).tolist()


#Script for checking if any Museum Ids in Museums Dataframe match with Ids in numeric_ids_with_prices list made from ticket cost entities Dataframe
def check_id_in_museum_id(museum_id):
    for numeric_id, price in numeric_ids_with_prices:
        if numeric_id in museum_id:
            return price  
    return None  

#Dataframes of Museums with ticket entry cost and their number for each region and city
df_museums_complete['Ticket_Cost'] = df_museums_complete['Museum_ID'].apply(check_id_in_museum_id)
df_museum_ticket_cost = df_museums_complete[df_museums_complete['Ticket_Cost'].notnull()].reset_index(drop=True)
df_museum_ticket_cost['Ticket_Cost'] = df_museum_ticket_cost['Ticket_Cost'].str.replace(',', '.').astype(float).map('{:.2f}'.format)
df_museum_ticket_cost_region_counts = df_museum_ticket_cost.groupby(['Museum_Region', 'Ticket_Cost']).size().reset_index(name='Count')
df_museum_ticket_cost_city_counts = df_museum_ticket_cost.groupby(['Museum_City', 'Ticket_Cost']).size().reset_index(name='Count')

#Displaying dataframes for Museum free entry cost entities, their city and region count
display(df_museum_ticket_cost)
display(df_museum_ticket_cost_region_counts)
display(df_museum_ticket_cost_city_counts)

#CSV of all above Dataframes
# csv_file_museums__ticket_cost_price = "Museums_Ticket_Cost_Price.csv"
# df_museum_ticket_cost.to_csv(csv_file_museums__ticket_cost_price, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums__ticket_cost_price}")

# csv_file_museums__ticket_cost_region_count = "Museums_Ticket_Cost_Region_count.csv"
# df_museum_ticket_cost_region_counts.to_csv(csv_file_museums__ticket_cost_region_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums__ticket_cost_region_count}")

# csv_file_museums__ticket_cost_city_count = "Museums_Ticket_Cost_City_count.csv"
# df_museum_ticket_cost_city_counts.to_csv(csv_file_museums__ticket_cost_city_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_museums__ticket_cost_city_count}")
# Out:
#                                               Museum_ID  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1284  http://dati.beniculturali.it/mibact/luoghi/res...
# 1285  http://dati.beniculturali.it/mibact/luoghi/res...
# 1286  http://dati.beniculturali.it/mibact/luoghi/res...
# 1287  http://dati.beniculturali.it/mibact/luoghi/res...
# 1288  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                             Museum_Name  \
# 0     Musei sistini del Piceno - Museo di arte sacra...
# 1             Parco Poesia Pascoli - Museo Casa Pascoli
# 2     Museo di arte contemporanea Giuseppe e Titina ...
# 3                       Museo delle navi romane di Nemi
# 4     Musei sistini del Piceno - Museo vescovile di ...
# ...                                                 ...
# 1284                      Museo del merletto di Rapallo
# 1285  MAXXI - Museo nazionale delle arti del XXI secolo
# 1286                            Musei civici di Sarnano
# 1287                                        Villa Croce
# 1288                Museo civico archeologico di Padria
#
#                                             Museum_City  \
# 0     http://dati.beniculturali.it/mibact/luoghi/res...
# 1     http://dati.beniculturali.it/mibact/luoghi/res...
# 2     http://dati.beniculturali.it/mibact/luoghi/res...
# 3     http://dati.beniculturali.it/mibact/luoghi/res...
# 4     http://dati.beniculturali.it/mibact/luoghi/res...
# ...                                                 ...
# 1284  http://dati.beniculturali.it/mibact/luoghi/res...
# 1285  http://dati.beniculturali.it/mibact/luoghi/res...
# 1286  http://dati.beniculturali.it/mibact/luoghi/res...
# 1287  http://dati.beniculturali.it/mibact/luoghi/res...
# 1288  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                           Museum_Region Ticket_Cost
# 0     http://dati.beniculturali.it/mibact/luoghi/res...        1.00
# 1     http://dati.beniculturali.it/mibact/luoghi/res...        3.00
# 2     http://dati.beniculturali.it/mibact/luoghi/res...        2.00
# 3     http://dati.beniculturali.it/mibact/luoghi/res...        5.00
# 4     http://dati.beniculturali.it/mibact/luoghi/res...        1.00
# ...                                                 ...         ...
# 1284  http://dati.beniculturali.it/mibact/luoghi/res...        3.00
# 1285  http://dati.beniculturali.it/mibact/luoghi/res...       12.00
# 1286  http://dati.beniculturali.it/mibact/luoghi/res...        5.00
# 1287  http://dati.beniculturali.it/mibact/luoghi/res...        5.00
# 1288  http://dati.beniculturali.it/mibact/luoghi/res...        1.00
#
# [1289 rows x 5 columns]
#                                          Museum_Region Ticket_Cost  Count
# 0    http://dati.beniculturali.it/mibact/luoghi/res...        1.00      6
# 1    http://dati.beniculturali.it/mibact/luoghi/res...        1.50      1
# 2    http://dati.beniculturali.it/mibact/luoghi/res...        1.70      1
# 3    http://dati.beniculturali.it/mibact/luoghi/res...        2.00      6
# 4    http://dati.beniculturali.it/mibact/luoghi/res...        2.50      1
# ..                                                 ...         ...    ...
# 284  http://dati.beniculturali.it/mibact/luoghi/res...        5.00      9
# 285  http://dati.beniculturali.it/mibact/luoghi/res...        6.00      6
# 286  http://dati.beniculturali.it/mibact/luoghi/res...        7.00      3
# 287  http://dati.beniculturali.it/mibact/luoghi/res...        8.00      2
# 288  http://dati.beniculturali.it/mibact/luoghi/res...        9.00      2
#
# [289 rows x 3 columns]
#                                             Museum_City Ticket_Cost  Count
# 0     http://dati.beniculturali.it/mibact/luoghi/res...        3.00      1
# 1     http://dati.beniculturali.it/mibact/luoghi/res...        5.00      1
# 2     http://dati.beniculturali.it/mibact/luoghi/res...        1.50      1
# 3     http://dati.beniculturali.it/mibact/luoghi/res...        4.00      2
# 4     http://dati.beniculturali.it/mibact/luoghi/res...        4.00      1
# ...                                                 ...         ...    ...
# 1030  http://dati.beniculturali.it/mibact/luoghi/res...        5.00      1
# 1031  http://dati.beniculturali.it/mibact/luoghi/res...        2.00      1
# 1032  http://dati.beniculturali.it/mibact/luoghi/res...        5.00      1
# 1033  http://dati.beniculturali.it/mibact/luoghi/res...        5.00      1
# 1034  http://dati.beniculturali.it/mibact/luoghi/res...        3.00      1
#
# [1035 rows x 3 columns]

# %%
#CHECKING FOR LIBRARIES WITH FREE ENTRY

#Script for extracting IDs from Dataframe of Entites with a Free Entry cost

import re
def extract_id(entity_id):
    match = re.search(r'/(\d+)_', entity_id)
    if match:
        return match.group(1)  
    return None  

numeric_ids = df_free_entry['Entity_ID'].apply(extract_id).tolist()


#Script for checking if any Library Ids in Library Dataframe match with Ids in numeric_ids list made from free enty entities Dataframe
def check_id_in_library_id(library_id):
    for numeric_id in numeric_ids:
        if numeric_id in library_id:
            return 'Free Entry' 
    return None

#Dataframes of Libraries with free entry cost and their number for each region
library_df['Ticket_Cost'] = library_df['Library_ID'].apply(check_id_in_library_id)
df_library_free_entry_cost = library_df[library_df['Ticket_Cost'] == 'Free Entry'].reset_index(drop=True)
df_library_free_entry_region_counts = df_library_free_entry_cost.groupby(['Library_Region', 'Ticket_Cost']).size().reset_index(name='Count')
df_library_free_entry_city_counts = df_library_free_entry_cost.groupby(['Library_City', 'Ticket_Cost']).size().reset_index(name='Count')

#Displaying dataframes for libraries entites with a free entry and their region/city count
display(df_library_free_entry_cost)
display(df_library_free_entry_region_counts)
display(df_library_free_entry_city_counts)

#CSV of all above DataFrame
# csv_file_library_free_ticket_cost_price = "library_free_entry_Cost_Price.csv"
# df_library_free_entry_cost.to_csv(csv_file_library_free_ticket_cost_price, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_library_free_ticket_cost_price}")

# csv_file_library_free_entry_region_count = "library_Free_Entry_region_count.csv"
# df_library_free_entry_region_counts.to_csv(csv_file_library_free_entry_region_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_library_free_entry_region_count}")

# csv_file_library_free_entry_city_count = "library_Free_Entry_city_count.csv"
# df_library_free_entry_city_counts.to_csv(csv_file_library_free_entry_city_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_library_free_entry_city_count}")
# Out:
#                                            Library_ID  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...
# 1   http://dati.beniculturali.it/mibact/luoghi/res...
# 2   http://dati.beniculturali.it/mibact/luoghi/res...
# 3   http://dati.beniculturali.it/mibact/luoghi/res...
# 4   http://dati.beniculturali.it/mibact/luoghi/res...
# 5   http://dati.beniculturali.it/mibact/luoghi/res...
# 6   http://dati.beniculturali.it/mibact/luoghi/res...
# 7   http://dati.beniculturali.it/mibact/luoghi/res...
# 8   http://dati.beniculturali.it/mibact/luoghi/res...
# 9   http://dati.beniculturali.it/mibact/luoghi/res...
# 10  http://dati.beniculturali.it/mibact/luoghi/res...
# 11  http://dati.beniculturali.it/mibact/luoghi/res...
# 12  http://dati.beniculturali.it/mibact/luoghi/res...
# 13  http://dati.beniculturali.it/mibact/luoghi/res...
# 14  http://dati.beniculturali.it/mibact/luoghi/res...
# 15  http://dati.beniculturali.it/mibact/luoghi/res...
# 16  http://dati.beniculturali.it/mibact/luoghi/res...
# 17  http://dati.beniculturali.it/mibact/luoghi/res...
# 18  http://dati.beniculturali.it/mibact/luoghi/res...
# 19  http://dati.beniculturali.it/mibact/luoghi/res...
# 20  http://dati.beniculturali.it/mibact/luoghi/res...
# 21  http://dati.beniculturali.it/mibact/luoghi/res...
# 22  http://dati.beniculturali.it/mibact/luoghi/res...
# 23  http://dati.beniculturali.it/mibact/luoghi/res...
# 24  http://dati.beniculturali.it/mibact/luoghi/res...
# 25  http://dati.beniculturali.it/mibact/luoghi/res...
# 26  http://dati.beniculturali.it/mibact/luoghi/res...
# 27  http://dati.beniculturali.it/mibact/luoghi/res...
# 28  http://dati.beniculturali.it/mibact/luoghi/res...
# 29  http://dati.beniculturali.it/mibact/luoghi/res...
# 30  http://dati.beniculturali.it/mibact/luoghi/res...
# 31  http://dati.beniculturali.it/mibact/luoghi/res...
# 32  http://dati.beniculturali.it/mibact/luoghi/res...
# 33  http://dati.beniculturali.it/mibact/luoghi/res...
# 34  http://dati.beniculturali.it/mibact/luoghi/res...
# 35  http://dati.beniculturali.it/mibact/luoghi/res...
# 36  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                          Library_Name  \
# 0                              Biblioteca Casanatense
# 1                         Biblioteca Statale di Lucca
# 2                              Biblioteca Riccardiana
# 3                      Biblioteca Medicea Laurenziana
# 4                   Biblioteca Medica Statale di Roma
# 5                  Biblioteca Universitaria di Padova
# 6                      Biblioteca statale di Macerata
# 7                            Biblioteca Vallicelliana
# 8   Biblioteca Statale del Monumento Nazionale di ...
# 9                Biblioteca Universitaria di Cagliari
# 10                 Biblioteca statale Antonio Baldini
# 11  Biblioteca Statale del Monumento Nazionale di ...
# 12                      Biblioteca statale di Cremona
# 13       Biblioteca di storia moderna e contemporanea
# 14  Complesso monumentale della Pilotta - Bibliote...
# 15  Biblioteca Statale Annessa al Monumento Nazion...
# 16  Pinacoteca di Brera - Biblioteca Nazionale Bra...
# 17              Biblioteca nazionale centrale di Roma
# 18              Biblioteca Universitaria Alessandrina
# 19  Biblioteca Statale del Monumento Nazionale di ...
# 20             Biblioteca statale Isontina di Gorizia
# 21                 Biblioteca Universitaria di Genova
# 22                  Biblioteca Universitaria di Pavia
# 23  Biblioteca Statale del Monumento Nazionale di ...
# 24                 Biblioteca Universitaria di Napoli
# 25  Biblioteca Statale del monumento nazionale di ...
# 26  Biblioteca Nazionale di Napoli "Vittorio Emanu...
# 27  Biblioteca statale del monumento nazionale del...
# 28  Gallerie estensi - Biblioteca estense universi...
# 29           Biblioteca Nazionale Centrale di Firenze
# 30  Biblioteca statale del Monumento nazionale di ...
# 31                   Biblioteca universitaria di Pisa
# 32       Biblioteca nazionale universitaria di Torino
# 33                            Biblioteca Marucelliana
# 34                Biblioteca Universitaria di Sassari
# 35         Biblioteca Statale Stelio Crise di Trieste
# 36                    Biblioteca Nazionale di Potenza
#
#                                          Library_City  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...
# 1   http://dati.beniculturali.it/mibact/luoghi/res...
# 2   http://dati.beniculturali.it/mibact/luoghi/res...
# 3   http://dati.beniculturali.it/mibact/luoghi/res...
# 4   http://dati.beniculturali.it/mibact/luoghi/res...
# 5   http://dati.beniculturali.it/mibact/luoghi/res...
# 6   http://dati.beniculturali.it/mibact/luoghi/res...
# 7   http://dati.beniculturali.it/mibact/luoghi/res...
# 8   http://dati.beniculturali.it/mibact/luoghi/res...
# 9   http://dati.beniculturali.it/mibact/luoghi/res...
# 10  http://dati.beniculturali.it/mibact/luoghi/res...
# 11  http://dati.beniculturali.it/mibact/luoghi/res...
# 12  http://dati.beniculturali.it/mibact/luoghi/res...
# 13  http://dati.beniculturali.it/mibact/luoghi/res...
# 14  http://dati.beniculturali.it/mibact/luoghi/res...
# 15  http://dati.beniculturali.it/mibact/luoghi/res...
# 16  http://dati.beniculturali.it/mibact/luoghi/res...
# 17  http://dati.beniculturali.it/mibact/luoghi/res...
# 18  http://dati.beniculturali.it/mibact/luoghi/res...
# 19  http://dati.beniculturali.it/mibact/luoghi/res...
# 20  http://dati.beniculturali.it/mibact/luoghi/res...
# 21  http://dati.beniculturali.it/mibact/luoghi/res...
# 22  http://dati.beniculturali.it/mibact/luoghi/res...
# 23  http://dati.beniculturali.it/mibact/luoghi/res...
# 24  http://dati.beniculturali.it/mibact/luoghi/res...
# 25  http://dati.beniculturali.it/mibact/luoghi/res...
# 26  http://dati.beniculturali.it/mibact/luoghi/res...
# 27  http://dati.beniculturali.it/mibact/luoghi/res...
# 28  http://dati.beniculturali.it/mibact/luoghi/res...
# 29  http://dati.beniculturali.it/mibact/luoghi/res...
# 30  http://dati.beniculturali.it/mibact/luoghi/res...
# 31  http://dati.beniculturali.it/mibact/luoghi/res...
# 32  http://dati.beniculturali.it/mibact/luoghi/res...
# 33  http://dati.beniculturali.it/mibact/luoghi/res...
# 34  http://dati.beniculturali.it/mibact/luoghi/res...
# 35  http://dati.beniculturali.it/mibact/luoghi/res...
# 36  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                        Library_Region Library_Latitude  \
# 0   http://dati.beniculturali.it/mibact/luoghi/res...        41.898148
# 1   http://dati.beniculturali.it/mibact/luoghi/res...          43.8449
# 2   http://dati.beniculturali.it/mibact/luoghi/res...         43.77558
# 3   http://dati.beniculturali.it/mibact/luoghi/res...        43.774815
# 4   http://dati.beniculturali.it/mibact/luoghi/res...         0.040255
# 5   http://dati.beniculturali.it/mibact/luoghi/res...         45.40711
# 6   http://dati.beniculturali.it/mibact/luoghi/res...         43.30105
# 7   http://dati.beniculturali.it/mibact/luoghi/res...        41.898186
# 8   http://dati.beniculturali.it/mibact/luoghi/res...        41.925537
# 9   http://dati.beniculturali.it/mibact/luoghi/res...        39.217236
# 10  http://dati.beniculturali.it/mibact/luoghi/res...         41.91954
# 11  http://dati.beniculturali.it/mibact/luoghi/res...        41.490738
# 12  http://dati.beniculturali.it/mibact/luoghi/res...        45.138042
# 13  http://dati.beniculturali.it/mibact/luoghi/res...        41.894035
# 14  http://dati.beniculturali.it/mibact/luoghi/res...         44.80498
# 15  http://dati.beniculturali.it/mibact/luoghi/res...        41.787067
# 16  http://dati.beniculturali.it/mibact/luoghi/res...        45.471947
# 17  http://dati.beniculturali.it/mibact/luoghi/res...        41.906784
# 18  http://dati.beniculturali.it/mibact/luoghi/res...         41.90336
# 19  http://dati.beniculturali.it/mibact/luoghi/res...         45.36541
# 20  http://dati.beniculturali.it/mibact/luoghi/res...        45.946304
# 21  http://dati.beniculturali.it/mibact/luoghi/res...         44.41616
# 22  http://dati.beniculturali.it/mibact/luoghi/res...         45.18673
# 23  http://dati.beniculturali.it/mibact/luoghi/res...        45.395912
# 24  http://dati.beniculturali.it/mibact/luoghi/res...        40.847164
# 25  http://dati.beniculturali.it/mibact/luoghi/res...        42.207504
# 26  http://dati.beniculturali.it/mibact/luoghi/res...         40.83619
# 27  http://dati.beniculturali.it/mibact/luoghi/res...         40.68232
# 28  http://dati.beniculturali.it/mibact/luoghi/res...         44.64811
# 29  http://dati.beniculturali.it/mibact/luoghi/res...        43.766922
# 30  http://dati.beniculturali.it/mibact/luoghi/res...        41.667736
# 31  http://dati.beniculturali.it/mibact/luoghi/res...          43.7152
# 32  http://dati.beniculturali.it/mibact/luoghi/res...        45.068684
# 33  http://dati.beniculturali.it/mibact/luoghi/res...        43.771034
# 34  http://dati.beniculturali.it/mibact/luoghi/res...        40.722702
# 35  http://dati.beniculturali.it/mibact/luoghi/res...         45.64559
# 36  http://dati.beniculturali.it/mibact/luoghi/res...        40.634987
#
#    Library_Longitude Ticket_Cost
# 0          12.479639  Free Entry
# 1          10.501189  Free Entry
# 2          11.255349  Free Entry
# 3          11.254537  Free Entry
# 4          -0.010042  Free Entry
# 5          11.880526  Free Entry
# 6          13.448922  Free Entry
# 7          12.469432  Free Entry
# 8          13.104736  Free Entry
# 9           9.115117  Free Entry
# 10          12.48609  Free Entry
# 11          13.82541  Free Entry
# 12         10.021977  Free Entry
# 13         12.478293  Free Entry
# 14           10.3259  Free Entry
# 15         12.667435  Free Entry
# 16          9.187837  Free Entry
# 17         12.504962  Free Entry
# 18         12.515426  Free Entry
# 19          11.73515  Free Entry
# 20          13.62364  Free Entry
# 21          8.924084  Free Entry
# 22          9.155909  Free Entry
# 23         11.879983  Free Entry
# 24          14.25703  Free Entry
# 25         12.729794  Free Entry
# 26         14.249669  Free Entry
# 27         14.691221  Free Entry
# 28         10.921424  Free Entry
# 29         11.262235  Free Entry
# 30         13.436525  Free Entry
# 31         10.407801  Free Entry
# 32           7.68633  Free Entry
# 33            11.248  Free Entry
# 34          8.563728  Free Entry
# 35         13.763095  Free Entry
# 36         15.786017  Free Entry
#                                        Library_Region Ticket_Cost  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 1   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      3
# 2   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 3   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 4   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     12
# 5   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 6   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      3
# 7   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 8   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 9   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 10  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      6
# 11  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      3
#                                          Library_City Ticket_Cost  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 1   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 2   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 3   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 4   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 5   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      4
# 6   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 7   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 8   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 9   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 10  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 11  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 12  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 13  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 14  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 15  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 16  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 17  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 18  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 19  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 20  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 21  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 22  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 23  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 24  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 25  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1

# %%
#Finding if there is any library with a TICKET COST for entry (only 1 found!)

import re
def extract_id(entity_id):
    match = re.search(r'/(\d+)_', entity_id)
    if match:
        numeric_id = match.group(1)  
        price = df_ticket_cost.loc[df_ticket_cost['Entity_ID'] == entity_id, 'Entry_Price'].iloc[0]  
        return (numeric_id, price)  
    return None  
numeric_ids_with_prices= df_ticket_cost['Entity_ID'].apply(extract_id).tolist()


#Cheking if any library ids of Libraries Dataframe in ticket cost dataframe entities
def check_id_in_library_id(library_id):
    for numeric_id, price in numeric_ids_with_prices:
        if numeric_id in library_id:
            return price  
    return None  
library_df['Ticket_Cost'] = library_df['Library_ID'].apply(check_id_in_library_id)
df_library_ticket_cost = library_df[library_df['Ticket_Cost'].notnull()].reset_index(drop=True)

#removing wrong matches from dataframes of library ticket cost
IDs_to_remove=["http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/117195",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/117246",
                "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/117148"
                ]
df_library_ticket_cost = df_library_ticket_cost[~df_library_ticket_cost['Library_ID'].isin(IDs_to_remove)]


df_library_ticket_cost['Ticket_Cost'] = df_library_ticket_cost['Ticket_Cost'].str.replace(',', '.').astype(float).map('{:.2f}'.format)
df_library_ticket_cost_region_counts = df_library_ticket_cost.groupby(['Library_Region', 'Ticket_Cost']).size().reset_index(name='Count')
df_library_ticket_cost_city_count = df_library_ticket_cost.groupby(['Library_City', 'Ticket_Cost']).size().reset_index(name='Count')

#Displaying library ticket cost dataframe and the region/city count
display(df_library_ticket_cost)
display(df_library_ticket_cost_region_counts)
display(df_library_ticket_cost_city_count)
# Out:
#                                           Library_ID  \
# 1  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                         Library_Name  \
# 1  Biblioteca nazionale Marciana - Sale monumenta...
#
#                                         Library_City  \
# 1  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                       Library_Region Library_Latitude  \
# 1  http://dati.beniculturali.it/mibact/luoghi/res...        45.434067
#
#   Library_Longitude Ticket_Cost
# 1         12.334472       25.00
#                                       Library_Region Ticket_Cost  Count
# 0  http://dati.beniculturali.it/mibact/luoghi/res...       25.00      1
#                                         Library_City Ticket_Cost  Count
# 0  http://dati.beniculturali.it/mibact/luoghi/res...       25.00      1

# %%
#CHEKING FOR ANY ARCHIVE WITH A FREE ENTRY COST

#Script for extracting IDs from Dataframe of Entites with a Free Entry cost

import re
def extract_id(entity_id):
    match = re.search(r'/(\d+)_', entity_id)
    if match:
        return match.group(1)  
    return None  

numeric_ids = df_free_entry['Entity_ID'].apply(extract_id).tolist()

#Script for checking if any Archive Ids in Library Dataframe match with Ids in numeric_ids list made from free enty entities Dataframe
def check_id_in_archive_id(archive_id):
    for numeric_id in numeric_ids:
        if numeric_id in archive_id:
            return 'Free Entry' 
    return None

#Dataframes of Archivies with free entry cost and their number for each region
df_archives['Ticket_Cost'] = df_archives['Archive_ID'].apply(check_id_in_archive_id)
df_archive_free_ticket_cost = df_archives[df_archives['Ticket_Cost'] == 'Free Entry'].reset_index(drop=True)
df_archive_free_entry_region_counts = df_archive_free_ticket_cost.groupby(['Archive_Region', 'Ticket_Cost']).size().reset_index(name='Count')
df_archive_free_entry_city_counts = df_archive_free_ticket_cost.groupby(['Archive_City', 'Ticket_Cost']).size().reset_index(name='Count')

#Displaying dataframes of archive free entry entities and the region/city count
display(df_archive_free_ticket_cost)
display(df_archive_free_entry_region_counts)
display(df_archive_free_entry_city_counts)

#CSV of above Dataframes
# csv_file_archive_free_entry_cost = "Archive__free_entry_cost.csv"
# df_archive_free_ticket_cost.to_csv(csv_file_archive_free_entry_cost, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_archive_free_entry_cost }")

# csv_file_archive_free_entry_region = "Archive_Free_Entry_region_count.csv"
# df_archive_free_entry_region_counts.to_csv(csv_file_archive_free_entry_region, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_archive_free_entry_region}")

# csv_file_archive_free_entry_city_count = "Archive_Free_Entry_city_count.csv"
# df_archive_free_entry_region_counts.to_csv(csv_file_archive_free_entry_city_count, index=False, encoding='utf-8')
# print(f"Results have been written to {csv_file_archive_free_entry_city_count}")
# Out:
#                                             Archive_ID  \
# 0    http://dati.beniculturali.it/mibact/luoghi/res...
# 1    http://dati.beniculturali.it/mibact/luoghi/res...
# 2    http://dati.beniculturali.it/mibact/luoghi/res...
# 3    http://dati.beniculturali.it/mibact/luoghi/res...
# 4    http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                 ...
# 110  http://dati.beniculturali.it/mibact/luoghi/res...
# 111  http://dati.beniculturali.it/mibact/luoghi/res...
# 112  http://dati.beniculturali.it/mibact/luoghi/res...
# 113  http://dati.beniculturali.it/mibact/luoghi/res...
# 114  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                        Archive_Name  \
# 0                Archivio di Stato di Reggio Emilia
# 1                       Archivio di Stato di Trento
# 2    Archivio di Stato di Bologna, Sezione di Imola
# 3                     Archivio centrale dello Stato
# 4      Archivio di Stato di Ancona. Sede distaccata
# ..                                              ...
# 110                                Domus mazziniana
# 111                       Archivio della fotografia
# 112                Archivio Storico Regione Liguria
# 113                        Villa Vicentini Miniussi
# 114                  Collezione storica ATC Bologna
#
#                                           Archive_City  \
# 0    http://dati.beniculturali.it/mibact/luoghi/res...
# 1    http://dati.beniculturali.it/mibact/luoghi/res...
# 2    http://dati.beniculturali.it/mibact/luoghi/res...
# 3    http://dati.beniculturali.it/mibact/luoghi/res...
# 4    http://dati.beniculturali.it/mibact/luoghi/res...
# ..                                                 ...
# 110  http://dati.beniculturali.it/mibact/luoghi/res...
# 111  http://dati.beniculturali.it/mibact/luoghi/res...
# 112  http://dati.beniculturali.it/mibact/luoghi/res...
# 113  http://dati.beniculturali.it/mibact/luoghi/res...
# 114  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                         Archive_Region Ticket_Cost
# 0    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 1    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 2    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 3    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 4    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# ..                                                 ...         ...
# 110  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 111  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 112  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 113  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
# 114  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry
#
# [115 rows x 5 columns]
#                                        Archive_Region Ticket_Cost  Count
# 0   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 1   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 2   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 3   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      4
# 4   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     12
# 5   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      5
# 6   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 7   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      5
# 8   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      7
# 9   http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     10
# 10  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 11  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      8
# 12  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      3
# 13  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      4
# 14  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      8
# 15  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry     10
# 16  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      2
# 17  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      6
# 18  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      6
#                                           Archive_City Ticket_Cost  Count
# 0    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 1    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 2    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      3
# 3    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 4    http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# ..                                                 ...         ...    ...
# 102  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 103  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 104  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 105  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
# 106  http://dati.beniculturali.it/mibact/luoghi/res...  Free Entry      1
#
# [107 rows x 3 columns]

# %%
#CHEKING FOR ANY ARCHIVE WITH A TICKET COST

#Finding if there is any archive with a TICKET COST for entry (only 1 found!)

import re
def extract_id(entity_id):
    match = re.search(r'/(\d+)_', entity_id)
    if match:
        numeric_id = match.group(1)  
        price = df_ticket_cost.loc[df_ticket_cost['Entity_ID'] == entity_id, 'Entry_Price'].iloc[0]  
        return (numeric_id, price)  
    return None  
numeric_ids_with_prices= df_ticket_cost['Entity_ID'].apply(extract_id).tolist()


#Script for checking if any Archive Ids in Library Dataframe match with Ids in numeric_ids list made from TICKET COST entities Dataframe
def check_id_in_archive_id(archive_id):
    for numeric_id, price in numeric_ids_with_prices:
        if numeric_id in archive_id:
            return price  
    return None  



#removing wrong matches from dataframes of archive ticket cost 
df_archives['Ticket_Cost'] = df_archives['Archive_ID'].apply(check_id_in_archive_id)
df_archive_ticket_cost = df_archives[df_archives['Ticket_Cost'].notnull()].reset_index(drop=True)
IDs_to_remove=["http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/120075",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/117164",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/120161",
               "http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/120074"
                ]
df_archive_ticket_cost = df_archive_ticket_cost[~df_archive_ticket_cost['Archive_ID'].isin(IDs_to_remove)]
df_archive_ticket_cost['Ticket_Cost'] = df_archive_ticket_cost['Ticket_Cost'].str.replace(',', '.').astype(float).map('{:.2f}'.format)
df_archive_ticket_cost_region_counts = df_archive_ticket_cost.groupby(['Archive_Region', 'Ticket_Cost']).size().reset_index(name='Count')
df_archive_ticket_cost_city_counts = df_archive_ticket_cost.groupby(['Archive_City', 'Ticket_Cost']).size().reset_index(name='Count')


#Displaying dataframes of archive ticket cost entites and the region/city count
display(df_archive_ticket_cost)
display(df_archive_ticket_cost_region_counts)
display(df_archive_ticket_cost_city_counts)
# Out:
#                                           Archive_ID Archive_Name  \
# 4  http://dati.beniculturali.it/mibact/luoghi/res...   Casa Zegna
#
#                                         Archive_City  \
# 4  http://dati.beniculturali.it/mibact/luoghi/res...
#
#                                       Archive_Region Ticket_Cost
# 4  http://dati.beniculturali.it/mibact/luoghi/res...        3.00
#                                       Archive_Region Ticket_Cost  Count
# 0  http://dati.beniculturali.it/mibact/luoghi/res...        3.00      1
#                                         Archive_City Ticket_Cost  Count
# 0  http://dati.beniculturali.it/mibact/luoghi/res...        3.00      1
